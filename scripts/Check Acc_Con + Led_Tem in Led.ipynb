# %%
import os
from os.path import join
from adin.settings import BASE_DIR

from adin.utils.date_progression import nextmonthlydate, nextyearlydate, previousmonthlydate, previousyearlydate

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 1000)

# %%
cls=Accountable_Concept

# %%
objs_df = pd.DataFrame(cls.objects.values()).drop(['state_change_user_id', 'state_change_date', 'state'], axis=1)
sorted_objs_df = objs_df.sort_values(by=['date'])
sorted_objs_df
# Out:
#                                                   code  \
# 302  Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 221  Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 222  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 439  Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 487  Canon Mensual Arriendo Inmueble^2021-12-01_C18...
# 265  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 508  Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 303  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 188  Canon Mensual Arriendo Inmueble^2021-12-20_A6N...
# 177  Canon Mensual Arriendo Inmueble^2021-12-21_A6N...
# 292  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 266  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 304  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 50   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 258  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 223  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# ...

# %%
user=User.objects.all()[0]
user
# Out:
# <User: leon>

# %%
def Register(acc_con_pk):
    acc_con = Accountable_Concept.objects.get(pk=acc_con_pk)
    led_tem = acc_con.accountable.accountable_transaction_type.get(transaction_type=acc_con.transaction_type).commit_template
    return led_tem.create_ledger(acc_con, acc_con.date, user)

# %%
sorted_objs_df.code.apply(lambda x: Register(x))
# Out:
# A6N-13N-62-S306^2018-06-01
# A6N-13N-62-S306^2018-06-01
# A6N-13N-62-S217^2018-12-01
# A6N-13N-62-S217^2018-12-01
# A6N-13N-62-S217^2018-12-01
# A6N-13N-62-S217^2018-12-01
# K1-17-57^2001-09-01
# K1-17-57^2001-09-01
# C18-1N-33^2021-10-01
# C18-1N-33^2021-10-01
# A6N-13N-62-S302^2021-08-01
# A6N-13N-62-S302^2021-08-01
# K1-17-37^2012-02-01
# K1-17-37^2012-02-01
# A6N-13N-62-S306^2018-06-01
# A6N-13N-62-S306^2018-06-01
# A6N-13N-62-S210^2017-03-20
# A6N-13N-62-S210^2017-03-20
# A6N-13N-62-S209^2006-03-21
# A6N-13N-62-S209^2006-03-21
# A6N-13N-62-S305^2021-02-01
# A6N-13N-62-S305^2021-02-01
# A6N-13N-62-S302^2021-08-01
# A6N-13N-62-S302^2021-08-01
# A6N-13N-62-S306^2018-06-01
# A6N-13N-62-S306^2018-06-01
# A6N-13N-62-S104^2021-08-01
# A6N-13N-62-S104^2021-08-01
# A6N-13N-62-S301^2021-08-01
# A6N-13N-62-S301^2021-08-01
# A6N-13N-62-S217^2018-12-01
# A6N-13N-62-S217^2018-12-01
# A6N-13N-62-S103^2020-06-01
# A6N-13N-62-S103^2020-06-01
# A6N-13N-62-S310^2021-12-01
# ...
