# %%
import os
from os.path import join
from adin.settings import BASE_DIR

from adin.utils.date_progression import nextmonthlydate, nextyearlydate, previousmonthlydate, previousyearlydate

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 1000)

# %%
cls=Accountable_Concept

# %%
objs_df = pd.DataFrame(cls.objects.values()).drop(['state_change_user_id', 'state_change_date', 'state'], axis=1).sort_values(by=['date']).assign(acc_con=objs_df.code.apply(lambda x: Accountable_Concept.objects.get(pk=x))).assign(ledger=sorted_objs_df.acc_con.apply(lambda x: x.Pending_Ledger(x.accountable.accountable_transaction_type.get(transaction_type=x.transaction_type).commit_template)))
objs_df
# Out:
#                                                   code  \
# 302  Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 221  Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 265  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 303  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 508  Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 439  Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 487  Canon Mensual Arriendo Inmueble^2021-12-01_C18...
# 222  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 188  Canon Mensual Arriendo Inmueble^2021-12-20_A6N...
# 177  Canon Mensual Arriendo Inmueble^2021-12-21_A6N...
# 304  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 70   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 144  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 334  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 344  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 60   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# ...

# %%
def Acc_Con_Commit(acc_con_pk):
    acc_con = Accountable_Concept.objects.get(pk=acc_con_pk)
    return acc_con.Pending_Ledger(acc_con.accountable.accountable_transaction_type.get(transaction_type=acc_con.transaction_type).commit_template)

# %%
referenced_objs_df=sorted_objs_df.assign(ledger=sorted_objs_df.acc_con.apply(lambda x: x.Pending_Ledger(x.accountable.accountable_transaction_type.get(transaction_type=x.transaction_type).commit_template)))
referenced_objs_df
# Out:
#                                                   code  \
# 302  Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 221  Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 265  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 303  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 508  Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 439  Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 487  Canon Mensual Arriendo Inmueble^2021-12-01_C18...
# 222  Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 188  Canon Mensual Arriendo Inmueble^2021-12-20_A6N...
# 177  Canon Mensual Arriendo Inmueble^2021-12-21_A6N...
# 304  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 70   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 144  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 334  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 344  Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 60   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# ...

# %%
referenced_objs_df[referenced_objs_df['ledger']==True]['code'].to_list()
# Out:
# ['Canon Mensual Arriendo Inmueble^2021-11-01_A6N-13N-62-S306^2018-06-01',
#  'Canon Mensual Arriendo Inmueble^2021-11-01_A6N-13N-62-S217^2018-12-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-01_A6N-13N-62-S302^2021-08-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-01_A6N-13N-62-S306^2018-06-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-01_K1-17-37^2012-02-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-01_K1-17-57^2001-09-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-01_C18-1N-33^2021-10-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-01_A6N-13N-62-S217^2018-12-01',
#  'Canon Mensual Arriendo Inmueble^2021-12-20_A6N-13N-62-S210^2017-03-20',
#  'Canon Mensual Arriendo Inmueble^2021-12-21_A6N-13N-62-S209^2006-03-21',
#  'Canon Mensual Arriendo Inmueble^2022-01-01_A6N-13N-62-S306^2018-06-01',
#  'Canon Mensual Arriendo Inmueble^2022-01-01_A6N-13N-62-S108^2016-12-01',
#  'Canon Mensual Arriendo Inmueble^2022-01-01_A6N-13N-62-S204^2021-09-01',
# ...

# %%
user=User.objects.all()[0]
user
# Out:
# <User: leon>

# %%
def Register(acc_con_pk):
    acc_con = Accountable_Concept.objects.get(pk=acc_con_pk)
    led_tem = acc_con.accountable.accountable_transaction_type.get(transaction_type=acc_con.transaction_type).bill_template
    return led_tem.create_ledger(acc_con, acc_con.date, user)

# %%
sorted_objs_df.code.apply(lambda x: Register(x))
# Out:
# 302     FV-00000001^2021-11-01_Monsalve Peña, John Jaime
# 221      FV-00000002^2021-11-01_Caicedo Matato, Liz Deny
# 222      FV-00000003^2021-12-01_Caicedo Matato, Liz Deny
# 439    FV-00000004^2021-12-01_Frenos y Direcciones Va...
# 487    FV-00000005^2021-12-01_Productos de Caucho y L...
# 265    FV-00000006^2021-12-01_Cordoba Salas, Nayza Ju...
# 508    FV-00000007^2021-12-01_Silva Riaños, Luis Fern...
# 303     FV-00000008^2021-12-01_Monsalve Peña, John Jaime
# 188        FV-00000009^2021-12-20_Prieto Duarte, Octavio
# 177    FV-00000010^2021-12-21_Escobar Pelaez, Jairo d...
# 292    FV-00000011^2022-01-01_Lozano Guzman, Yessica ...
# 266    FV-00000012^2022-01-01_Cordoba Salas, Nayza Ju...
# 304     FV-00000013^2022-01-01_Monsalve Peña, John Jaime
# 50     FV-00000014^2022-01-01_Campo Garcia, Lina Ginnery
# 258    FV-00000015^2022-01-01_Loaiza Largo, Carmen Lu...
# 223      FV-00000016^2022-01-01_Caicedo Matato, Liz Deny
# ...

# %%
nu_df=pd.DataFrame(Accountable_Concept.objects.values('code'))
nu_df
# Out:
#                                                   code
# 0    Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 1    Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 2    Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 3    Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 4    Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 5    Canon Mensual Arriendo Inmueble^2021-12-01_C18...
# 6    Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 7    Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 8    Canon Mensual Arriendo Inmueble^2021-12-20_A6N...
# 9    Canon Mensual Arriendo Inmueble^2021-12-21_A6N...
# 10   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 11   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 12   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 13   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 14   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 15   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# ...

# %%
obj_df=nu_df.assign(accountable_concept=nu_df.code.apply(lambda x: Accountable_Concept.objects.get(pk=x)))
obj_df
# Out:
#                                                   code  \
# 0    Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 1    Canon Mensual Arriendo Inmueble^2021-11-01_A6N...
# 2    Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 3    Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 4    Canon Mensual Arriendo Inmueble^2021-12-01_A6N...
# 5    Canon Mensual Arriendo Inmueble^2021-12-01_C18...
# 6    Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 7    Canon Mensual Arriendo Inmueble^2021-12-01_K1-...
# 8    Canon Mensual Arriendo Inmueble^2021-12-20_A6N...
# 9    Canon Mensual Arriendo Inmueble^2021-12-21_A6N...
# 10   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 11   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 12   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 13   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 14   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# 15   Canon Mensual Arriendo Inmueble^2022-01-01_A6N...
# ...

# %%
full_df=obj_df.assign(
    ledger_template=obj_df.accountable_concept.apply(lambda x: x.accountable.accountable_transaction_type.get(transaction_type__name='Canon Mensual Arriendo Inmueble').commit_template),
    ledger_type=obj_df.accountable_concept.apply(lambda x: x.accountable.accountable_transaction_type.get(transaction_type__name='Canon Mensual Arriendo Inmueble').commit_template.ledger_type),
    accountable=obj_df.accountable_concept.apply(lambda x: x.accountable),
    holder=obj_df.accountable_concept.apply(lambda x: x.accountable.ledger_holder()),
    third_party=obj_df.accountable_concept.apply(lambda x: x.accountable.ledger_third_party()),
    concept_date=obj_df.accountable_concept.apply(lambda x: x.date),
    concept_value=obj_df.accountable_concept.apply(lambda x: x.value)
).drop(['code'], axis=1).to_dict('records')
full_df
# Out:
# [{'accountable_concept': <Accountable_Concept: Canon Mensual Arriendo Inmueble^2021-11-01_A6N-13N-62-S217^2018-12-01>,
#   'ledger_template': <Ledger_Template: CA-Canon Mensual Arriendo Inmueble>,
#   'ledger_type': <Ledger_Type: Causación>,
#   'accountable': <Accountable: A6N-13N-62-S217^2018-12-01>,
#   'holder': <Person: Corkidi Tzuckerman, León>,
#   'third_party': <Person: Caicedo Matato, Liz Deny>,
#   'concept_date': datetime.date(2021, 11, 1),
#   'concept_value': 472000},
#  {'accountable_concept': <Accountable_Concept: Canon Mensual Arriendo Inmueble^2021-11-01_A6N-13N-62-S306^2018-06-01>,
#   'ledger_template': <Ledger_Template: CA-Canon Mensual Arriendo Inmueble>,
#   'ledger_type': <Ledger_Type: Causación>,
#   'accountable': <Accountable: A6N-13N-62-S306^2018-06-01>,
#   'holder': <Person: Corkidi Tzuckerman, León>,
#   'third_party': <Person: Monsalve Peña, John Jaime>,
#   'concept_date': datetime.date(2021, 11, 1),
#   'concept_value': 458000},
# ...
