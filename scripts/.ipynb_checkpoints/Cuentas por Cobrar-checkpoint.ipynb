# %%
import os
from accountables.utils.accounting_data import ACCOUNT_RECEIPT_PRIORITY
from accounting.models.ledger import LEDGER_RECEIPT_PRIORITY

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 500)

# %%
acc = Accountable.objects.get(pk='A6N-13N-62-O1^2015-01-01')
acc
# Out:
# <Accountable: A6N-13N-62-O1^2015-01-01>

# %%
objs_df=pd.DataFrame(Charge.objects.filter(account__in=[13802005, 13050505], concept__accountable=acc)\
                    .values('id', 'ledger', 'concept__accountable', 'account', 'account__name', 'concept__date', 'value'))
priority_df=objs_df.assign(priority=objs_df.apply(lambda x: ACCOUNT_RECEIPT_PRIORITY[x.account] + LEDGER_RECEIPT_PRIORITY[x.ledger[:2]], axis=1))
sorted_df=priority_df.sort_values(by=['concept__date', 'priority', 'value'])
sorted_df
# Out:
#       id       ledger      concept__accountable   account  \
# 0   2323  CA-00000040  A6N-13N-62-O1^2015-01-01  13802005
# 10  3283  FV-00000001  A6N-13N-62-O1^2015-01-01  13802005
# 11  3284  FV-00000001  A6N-13N-62-O1^2015-01-01  13802005
# 12  3286  RC-00000001  A6N-13N-62-O1^2015-01-01  13802005
# 1   2431  CA-00000094  A6N-13N-62-O1^2015-01-01  13802005
# 13  3287  FV-00000002  A6N-13N-62-O1^2015-01-01  13802005
# 14  3288  FV-00000002  A6N-13N-62-O1^2015-01-01  13802005
# 2   2541  CA-00000149  A6N-13N-62-O1^2015-01-01  13802005
# 3   2565  CA-00000161  A6N-13N-62-O1^2015-01-01  13802005
# 4   2735  CA-00000246  A6N-13N-62-O1^2015-01-01  13802005
# 5   2779  CA-00000268  A6N-13N-62-O1^2015-01-01  13802005
# 6   2867  CA-00000312  A6N-13N-62-O1^2015-01-01  13802005
# 7   2971  CA-00000364  A6N-13N-62-O1^2015-01-01  13802005
# 8   3075  CA-00000416  A6N-13N-62-O1^2015-01-01  13802005
# 9   3215  CA-00000486  A6N-13N-62-O1^2015-01-01  13802005
#
#                account__name concept__date    value  priority
# 0   Arrendamientos Inmuebles    2022-01-01  1065000        10
# 10  Arrendamientos Inmuebles    2022-01-01 -1065000        11
# 11  Arrendamientos Inmuebles    2022-01-01  1065000        11
# 12  Arrendamientos Inmuebles    2022-01-01 -1065000        12
# 1   Arrendamientos Inmuebles    2022-02-01  1065000        10
# 13  Arrendamientos Inmuebles    2022-02-01 -1065000        11
# 14  Arrendamientos Inmuebles    2022-02-01  1065000        11
# 2   Arrendamientos Inmuebles    2022-03-01  1065000        10
# 3   Arrendamientos Inmuebles    2022-04-01  1065000        10
# 4   Arrendamientos Inmuebles    2022-05-01  1065000        10
# 5   Arrendamientos Inmuebles    2022-06-01  1065000        10
# 6   Arrendamientos Inmuebles    2022-07-01  1065000        10
# 7   Arrendamientos Inmuebles    2022-08-01  1065000        10
# 8   Arrendamientos Inmuebles    2022-09-01  1065000        10
# 9   Arrendamientos Inmuebles    2022-10-01  1065000        10

# %%
def GetChargeDue(charge_id):
    cha=Charge.objects.get(pk=charge_id)
    if cha.ledger.type.abreviation == 'CA':
        if Charge.objects.filter(account=cha.account, concept=cha.concept, ledger__type__abreviation='FV', value=-cha.value).exists():
            return 0
        else:
            return cha.value
    elif cha.ledger.type.abreviation == 'FV' and cha.value < 0:
        if Charge.objects.filter(account=cha.account, concept=cha.concept, ledger__type__abreviation='CA', value=-cha.value).exists():
            return 0        
    elif cha.ledger.type.abreviation == 'FV' and cha.value > 0:
        receipt = Charge.objects.filter(account=cha.account, concept=cha.concept, ledger__type__abreviation='RC', value__lt=0).aggregate(receipt=Sum('value'))['receipt']
        return cha.value + receipt if receipt else cha.value
    else:
        return 0

# %%
def DueAge(_dueDate):
    bufferDate=_dueDate
    months=0
    days=0
    while bufferDate < datetime.date.today():
        if bufferDate + relativedelta(months=1) < datetime.date.today():
            months = months +1
        else:
            days=(datetime.date.today() - bufferDate).days
        bufferDate = bufferDate + relativedelta(months=1)
    return f'{months}, {days}'

# %%
due_df=sorted_df.assign(
    due_value=sorted_df.id.apply(lambda x: GetChargeDue(x)),
    due_age=sorted_df.concept__date.apply(lambda x: DueAge(x)))
due_df
# Out:
#       id       ledger      concept__accountable   account  \
# 0   2323  CA-00000040  A6N-13N-62-O1^2015-01-01  13802005
# 10  3283  FV-00000001  A6N-13N-62-O1^2015-01-01  13802005
# 11  3284  FV-00000001  A6N-13N-62-O1^2015-01-01  13802005
# 12  3286  RC-00000001  A6N-13N-62-O1^2015-01-01  13802005
# 1   2431  CA-00000094  A6N-13N-62-O1^2015-01-01  13802005
# 13  3287  FV-00000002  A6N-13N-62-O1^2015-01-01  13802005
# 14  3288  FV-00000002  A6N-13N-62-O1^2015-01-01  13802005
# 2   2541  CA-00000149  A6N-13N-62-O1^2015-01-01  13802005
# 3   2565  CA-00000161  A6N-13N-62-O1^2015-01-01  13802005
# 4   2735  CA-00000246  A6N-13N-62-O1^2015-01-01  13802005
# 5   2779  CA-00000268  A6N-13N-62-O1^2015-01-01  13802005
# 6   2867  CA-00000312  A6N-13N-62-O1^2015-01-01  13802005
# 7   2971  CA-00000364  A6N-13N-62-O1^2015-01-01  13802005
# 8   3075  CA-00000416  A6N-13N-62-O1^2015-01-01  13802005
# 9   3215  CA-00000486  A6N-13N-62-O1^2015-01-01  13802005
#
#                account__name concept__date    value  priority  due_value  \
# 0   Arrendamientos Inmuebles    2022-01-01  1065000        10          0
# 10  Arrendamientos Inmuebles    2022-01-01 -1065000        11          0
# 11  Arrendamientos Inmuebles    2022-01-01  1065000        11          0
# 12  Arrendamientos Inmuebles    2022-01-01 -1065000        12          0
# 1   Arrendamientos Inmuebles    2022-02-01  1065000        10          0
# 13  Arrendamientos Inmuebles    2022-02-01 -1065000        11          0
# 14  Arrendamientos Inmuebles    2022-02-01  1065000        11    1065000
# 2   Arrendamientos Inmuebles    2022-03-01  1065000        10    1065000
# 3   Arrendamientos Inmuebles    2022-04-01  1065000        10    1065000
# 4   Arrendamientos Inmuebles    2022-05-01  1065000        10    1065000
# 5   Arrendamientos Inmuebles    2022-06-01  1065000        10    1065000
# 6   Arrendamientos Inmuebles    2022-07-01  1065000        10    1065000
# 7   Arrendamientos Inmuebles    2022-08-01  1065000        10    1065000
# 8   Arrendamientos Inmuebles    2022-09-01  1065000        10    1065000
# 9   Arrendamientos Inmuebles    2022-10-01  1065000        10    1065000
#
#    due_age
# 0    10, 1
# 10   10, 1
# 11   10, 1
# 12   10, 1
# 1     9, 1
# 13    9, 1
# 14    9, 1
# 2     8, 1
# 3     7, 1
# 4     6, 1
# 5     5, 1
# 6     4, 1
# 7     3, 1
# 8     2, 1
# 9     1, 1

# %%
pending_df = due_df[due_df['due_value'] != 0].to_dict('records')
pending_df
# Out:
# [{'id': 3288,
#   'ledger': 'FV-00000002',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 2, 1),
#   'value': 1065000,
#   'priority': 11,
#   'due_value': 1065000,
#   'due_age': '9, 1'},
#  {'id': 2541,
#   'ledger': 'CA-00000149',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 3, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '8, 1'},
#  {'id': 2565,
#   'ledger': 'CA-00000161',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 4, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '7, 1'},
#  {'id': 2735,
#   'ledger': 'CA-00000246',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 5, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '6, 1'},
#  {'id': 2779,
#   'ledger': 'CA-00000268',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 6, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '5, 1'},
#  {'id': 2867,
#   'ledger': 'CA-00000312',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 7, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '4, 1'},
#  {'id': 2971,
#   'ledger': 'CA-00000364',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 8, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '3, 1'},
#  {'id': 3075,
#   'ledger': 'CA-00000416',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 9, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '2, 1'},
#  {'id': 3215,
#   'ledger': 'CA-00000486',
#   'concept__accountable': 'A6N-13N-62-O1^2015-01-01',
#   'account': 13802005,
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 10, 1),
#   'value': 1065000,
#   'priority': 10,
#   'due_value': 1065000,
#   'due_age': '1, 1'}]

# %%
due_df['due_value'].sum()
# Out:
# 9585000

# %%
due_df[due_df['due_value'] != 0]['due_age'].iloc[0]
# Out:
# '9, 1'

# %%
acc_con=Accountable_Concept.objects.all()[508]
acc_con
# Out:
# <Accountable_Concept: Canon Mensual Arriendo Inmueble^2021-12-01_K1-17-37^2012-02-01>

# %%
Charge.objects.exclude(state=0).filter(account__in=[account for account in ACCOUNT_RECEIPT_PRIORITY.keys()], concept=acc_con, value__gt=0, ledger__type__abreviation='FV').aggregate(receivable=Sum('value'))
# Out:
# {'receivable': 1713600}

# %%
Charge.objects.exclude(state=0).filter(account__in=[account for account in ACCOUNT_RECEIPT_PRIORITY.keys()], concept=acc_con, value__lt=0, ledger__type__abreviation='RC').aggregate(received=Sum('value')) if Charge.objects.exclude(state=0).filter(account__in=[account for account in ACCOUNT_RECEIPT_PRIORITY.keys()], concept=acc_con, value__lt=0, ledger__type__abreviation='RC').exists() else 0
# Out:
# 0
