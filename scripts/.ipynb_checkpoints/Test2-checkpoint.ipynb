# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
import csv
import adin.settings as st
from IPython.display import display
from references.forms.address_forms import AddressCreateModelForm
from django.contrib.auth.models import User

jpath = os.path.join
BASE_DIR = st.BASE_DIR

# %%
date_str = '2022-05-20'
class_name = 'Address'

# %%
df = pd.read_csv(jpath(BASE_DIR, f'_files/exports/{date_str}_{class_name.lower()}.csv'), keep_default_na=False).assign(class_name=class_name)
bi = pd.read_json(jpath(BASE_DIR, f'_files/_backup_info.json'))

# %%
df
# Out:
#      Unnamed: 0  state_change_user_id                 state_change_date  \
# 0             0                     1  2022-05-20 03:32:25.416881+00:00
# 1             1                     1  2022-05-20 03:32:25.431592+00:00
# 2             2                     1  2022-05-20 03:32:25.420986+00:00
# 3             3                     1  2022-05-20 03:32:25.424733+00:00
# 4             4                     1  2022-05-20 03:32:25.428102+00:00
# ..          ...                   ...                               ...
# 143         143                     1  2022-05-20 03:32:25.570614+00:00
# 144         144                     1  2022-05-20 03:32:25.542231+00:00
# 145         145                     1  2022-05-20 03:32:25.469116+00:00
# 146         146                     1  2022-05-20 03:32:25.585062+00:00
# 147         147                     1  2022-05-20 03:32:25.574149+00:00
#
#      state              code   country           region  city  street_type  \
# 0        1  A11N-7N-201-A103  Colombia  Valle del Cauca  Cali            0
# 1        1   A11N-7N-201-D22  Colombia  Valle del Cauca  Cali            0
# 2        1   A11N-7N-201-P28  Colombia  Valle del Cauca  Cali            0
# 3        1   A11N-7N-201-P29  Colombia  Valle del Cauca  Cali            0
# 4        1   A11N-7N-201-P61  Colombia  Valle del Cauca  Cali            0
# ..     ...               ...       ...              ...   ...          ...
# 143      1          K7-21-23  Colombia  Valle del Cauca  Cali            2
# 144      1           K8-15-1  Colombia  Valle del Cauca  Cali            2
# 145      1        K81-3A-125  Colombia  Valle del Cauca  Cali            2
# 146      1          K9-11-37  Colombia  Valle del Cauca  Cali            2
# 147      1          K9-11-50  Colombia  Valle del Cauca  Cali            2
#
#      street_number  ... numeral_letter  numeral_bis numeral_bis_complement  \
# 0               11  ...                       False
# 1               11  ...                       False
# 2               11  ...                       False
# 3               11  ...                       False
# 4               11  ...                       False
# ..             ...  ...            ...          ...                    ...
# 143              7  ...                       False
# 144              8  ...                       False
# 145             81  ...              0        False
# 146              9  ...                       False
# 147              9  ...                       False
#
#     numeral_coordinate  height_number interior_group_type  \
# 0                    0            201
# 1                    0            201
# 2                    0            201
# 3                    0            201
# 4                    0            201
# ..                 ...            ...                 ...
# 143                                23
# 144                                 1
# 145                               125
# 146                                37
# 147                                50
#
#      interior_group_code interior_type interior_code  class_name
# 0                                    0           103     Address
# 1                                    5            22     Address
# 2                                    4            28     Address
# 3                                    4            29     Address
# 4                                    4            61     Address
# ..                   ...           ...           ...         ...
# 143                                                      Address
# 144                                                      Address
# 145                                                      Address
# 146                                                      Address
# 147                                                      Address
#
# [148 rows x 25 columns]

# %%
bi
# Out:
#                                                        Address
# df_types     {'country': 'object', 'region': 'object', 'cit...
# fk_attrs                                                    {}
# value_attrs  [country, region, city, street_type, street_nu...

# %%
from os import listdir
from os.path import isfile, join

files_path = join(BASE_DIR, '_files/exports')
files = [file for file in listdir(files_path) if isfile(join(files_path, file))]
files
# Out:
# ['2022-05-20_contenttype.csv',
#  '2022-05-20_person_e_mail.csv',
#  '2022-05-20_person_address.csv',
#  '2022-05-20_permission.csv',
#  '2022-05-20_transaction_type.csv',
#  '2022-05-20_user.csv',
#  '2022-05-20_estate_appraisal.csv',
#  '2022-05-20_realty_estate.csv',
#  '2022-05-20_person_legal_person_natural.csv',
#  '2022-05-20_estate.csv',
#  '2022-05-20_person.csv',
#  '2022-05-20_lease_realty_person.csv',
#  '2022-05-20_ledger_type.csv',
#  '2022-05-20_lease_realty_realty.csv',
#  '2022-05-20_realty.csv',
#  '2022-05-20_accountable.csv',
#  '2022-05-20_lease_realty.csv',
#  '2022-05-20_address.csv',
#  '2022-05-20_phone.csv',
#  '2022-05-20_account.csv',
#  '2022-05-20_person_phone.csv',
#  '2022-05-20_logentry.csv',
#  '2022-05-20_group.csv',
#  '2022-05-20_puc.csv',
#  '2022-05-20_person_legal.csv',
#  '2022-05-20_e_mail.csv',
#  '2022-05-20_date_value.csv',
#  '2022-05-20_session.csv',
#  '2022-05-20_estate_person.csv',
#  '2022-05-20_person_natural.csv']

# %%
from os.path import join
from adin.settings import BASE_DIR

df_from_csv = None
data_dict = None

def data_load(load_info, load_list=None):
    timers = {}
    counter = 0
    if load_list:
        for element in load_list:
            model_load(load_info[element])
    else:
        for value in load_info.values():
            model_load(value)
    
def model_load(load_dict):
    df_from_csv = pd.read_csv(join(BASE_DIR, f"_files/exports/{load_dict['csv_name']}"), keep_default_na=False)\
        .drop(load_dict['to_drop'], axis=1)\
        .rename(columns=load_dict['to_rename'])
    data_dict = df_from_csv\
        .assign(**{column: df_from_csv[column].apply(lambda x: None if x == '' else x) for column in df_from_csv.columns})\
        .assign(**{column: df_from_csv[column].apply(lambda x: model.objects.get(pk=x)) for column, model in load_dict['fk_dict'].items()})\
        .assign(state=df_from_csv.state.apply(lambda x: 2))\
        .to_dict('index')
    load_dict['model'].objects.bulk_create([load_dict['model'](**data) for key, data in data_dict.items()])

# %%
df_from_csv

# %%
load_info = { 
            'puc' : {
                'csv_name' : '0_puc.csv',
                'fk_dict' : {'state_change_user': User},
                'model' : PUC,
                'to_drop' : ['Unnamed: 0', 'state_change_date'],
                'to_rename' : {'state_change_user_id':'state_change_user'}
                },
            'charge_factor' : {
                'csv_name' : '1_charge_factor.csv',
                'fk_dict' : {'state_change_user':User},
                'model' : Charge_Factor,
                'to_drop' : ['Unnamed: 0', 'state_change_date'],
                'to_rename' : {'state_change_user_id':'state_change_user'}
                },
            'factor_data' : {
                'csv_name' : '2_factor_data.csv',
                'fk_dict' : {'state_change_user':User, 'factor':Charge_Factor},
                'model' : Factor_Data,
                'to_drop' : ['Unnamed: 0', 'state_change_date'],
                'to_rename' : {'state_change_user_id':'state_change_user'}
                }
            }
load_list = ['factor_data']

data_load(load_info, load_list=load_list)

# %%
Address.objects.bulk_create([Address(**data) for key, data in dict.items()])
# Out:
# [<Addresss: A11N-7N-201-A103, Cali>,
#  <Addresss: A11N-7N-201-D22, Cali>,
#  <Addresss: A11N-7N-201-P28, Cali>,
#  <Addresss: A11N-7N-201-P29, Cali>,
#  <Addresss: A11N-7N-201-P61, Cali>,
#  <Addresss: A2B-73b-98, Cali>,
#  <Addresss: A3-19-36, Cali>,
#  <Addresss: A4N-14N-22, Cali>,
#  <Addresss: A5AN-23DN-68, Cali>,
#  <Addresss: A5N-5N-53, Cali>,
#  <Addresss: A6N-13N-62, Cali>,
#  <Addresss: A6N-13N-62-O1, Cali>,
#  <Addresss: A6N-13N-62-S101, Cali>,
#  <Addresss: A6N-13N-62-S102, Cali>,
#  <Addresss: A6N-13N-62-S103, Cali>,
#  <Addresss: A6N-13N-62-S104, Cali>,
#  <Addresss: A6N-13N-62-S105, Cali>,
#  <Addresss: A6N-13N-62-S106, Cali>,
#  <Addresss: A6N-13N-62-S107, Cali>,
#  <Addresss: A6N-13N-62-S108, Cali>,
#  <Addresss: A6N-13N-62-S109, Cali>,
#  <Addresss: A6N-13N-62-S110, Cali>,
#  <Addresss: A6N-13N-62-S111, Cali>,
#  <Addresss: A6N-13N-62-S112, Cali>,
#  <Addresss: A6N-13N-62-S114, Cali>,
#  <Addresss: A6N-13N-62-S201, Cali>,
#  <Addresss: A6N-13N-62-S202, Cali>,
#  <Addresss: A6N-13N-62-S203, Cali>,
#  <Addresss: A6N-13N-62-S204, Cali>,
#  <Addresss: A6N-13N-62-S205, Cali>,
#  <Addresss: A6N-13N-62-S206, Cali>,
#  <Addresss: A6N-13N-62-S207, Cali>,
#  <Addresss: A6N-13N-62-S208, Cali>,
#  <Addresss: A6N-13N-62-S209, Cali>,
#  <Addresss: A6N-13N-62-S210, Cali>,
#  <Addresss: A6N-13N-62-S211, Cali>,
#  <Addresss: A6N-13N-62-S212, Cali>,
#  <Addresss: A6N-13N-62-S214, Cali>,
#  <Addresss: A6N-13N-62-S215, Cali>,
#  <Addresss: A6N-13N-62-S216, Cali>,
#  <Addresss: A6N-13N-62-S217, Cali>,
#  <Addresss: A6N-13N-62-S218, Cali>,
#  <Addresss: A6N-13N-62-S219, Cali>,
#  <Addresss: A6N-13N-62-S220, Cali>,
#  <Addresss: A6N-13N-62-S221, Cali>,
#  <Addresss: A6N-13N-62-S222, Cali>,
#  <Addresss: A6N-13N-62-S301, Cali>,
#  <Addresss: A6N-13N-62-S302, Cali>,
#  <Addresss: A6N-13N-62-S303, Cali>,
#  <Addresss: A6N-13N-62-S304, Cali>,
#  <Addresss: A6N-13N-62-S305, Cali>,
#  <Addresss: A6N-13N-62-S306, Cali>,
#  <Addresss: A6N-13N-62-S307, Cali>,
#  <Addresss: A6N-13N-62-S308, Cali>,
#  <Addresss: A6N-13N-62-S309, Cali>,
#  <Addresss: A6N-13N-62-S310, Cali>,
#  <Addresss: A6N-13N-62-S311, Cali>,
#  <Addresss: A6N-13N-62-S312, Cali>,
#  <Addresss: A6N-13N-62-S314, Cali>,
#  <Addresss: A6N-13N-62-S315, Cali>,
#  <Addresss: A6N-13N-62-S316, Cali>,
#  <Addresss: A6N-13N-62-S317, Cali>,
#  <Addresss: A6N-13N-62-S318, Cali>,
#  <Addresss: A6N-13N-62-S319, Cali>,
#  <Addresss: A6N-13N-62-S320, Cali>,
#  <Addresss: A6N-13N-62-S321, Cali>,
#  <Addresss: A6N-13N-62-S322, Cali>,
#  <Addresss: A6N-13N-66, Cali>,
#  <Addresss: A6N-13N-68, Cali>,
#  <Addresss: A7N-24N-40, Cali>,
#  <Addresss: C11N-4A-9, Cali>,
#  <Addresss: C12-29B-78, Cali>,
#  <Addresss: C13-9-36, Cali>,
#  <Addresss: C15-29A-11, Cali>,
#  <Addresss: C17C-10C-16, Cali>,
#  <Addresss: C18-1N-33, Cali>,
#  <Addresss: C18-1N-39, Cali>,
#  <Addresss: C18-1N-41, Cali>,
#  <Addresss: C18-1N-43, Cali>,
#  <Addresss: C20-28-97, Pasto>,
#  <Addresss: C26B1-1-65, Cali>,
#  <Addresss: C28-20-22, Cali>,
#  <Addresss: C28-98-82, Cali>,
#  <Addresss: C30-1B-13, Cali>,
#  <Addresss: C30-1B-15-B1, Cali>,
#  <Addresss: C30-1B-15-B2, Cali>,
#  <Addresss: C30-1B-15-B3, Cali>,
#  <Addresss: C30-1B-15-B5, Cali>,
#  <Addresss: C30-1B-27, Cali>,
#  <Addresss: C30-1B-31, Cali>,
#  <Addresss: C31-1B-24, Cali>,
#  <Addresss: C31-1B-34, Cali>,
#  <Addresss: C31-1B-4, Cali>,
#  <Addresss: C31-1B-44, Cali>,
#  <Addresss: C31-1B-54, Cali>,
#  <Addresss: C31-1B-64, Cali>,
#  <Addresss: C31-1B-74, Cali>,
#  <Addresss: C31-1B-80, Cali>,
#  <Addresss: C34-40B-24, Cali>,
#  <Addresss: C3O-2-136-P14, Cali>,
#  <Addresss: C3O-2-140-A301, Cali>,
#  <Addresss: C40N-3-69, Cali>,
#  <Addresss: C42-95A-15, Cali>,
#  <Addresss: C6N-2N-71, Cali>,
#  <Addresss: C6O-6-89, Cali>,
#  <Addresss: C70-9-49, Cali>,
#  <Addresss: C9-5-31, Cali>,
#  <Addresss: C99-14-3, Cali>,
#  <Addresss: K1-17-37, Cali>,
#  <Addresss: K1-17-43, Cali>,
#  <Addresss: K1-17-47, Cali>,
#  <Addresss: K1-17-53, Cali>,
#  <Addresss: K1-17-57, Cali>,
#  <Addresss: K1-17-65, Cali>,
#  <Addresss: K1-31-84, Cali>,
#  <Addresss: K1-35-29, Cali>,
#  <Addresss: K1-35-29-B11, Cali>,
#  <Addresss: K1-35-29-B9, Cali>,
#  <Addresss: K11-7-85, Cali>,
#  <Addresss: K15-31-16, Cali>,
#  <Addresss: K1B-30-16, Cali>,
#  <Addresss: K1B-30-34, Cali>,
#  <Addresss: K1B-30-52, Cali>,
#  <Addresss: K1B-30-76, Cali>,
#  <Addresss: K28-40-21, Cali>,
#  <Addresss: K2C-29-36, Cali>,
#  <Addresss: K2C-30-15-B2, Cali>,
#  <Addresss: K2C-30-15-B3, Cali>,
#  <Addresss: K2C-30-27, Cali>,
#  <Addresss: K2C-30-29, Cali>,
#  <Addresss: K2C-30-3, Cali>,
#  <Addresss: K2C-30-51, Cali>,
#  <Addresss: K2C-30-9, Cali>,
#  <Addresss: K2N-21-53, Cali>,
#  <Addresss: K38-14-70, Cali>,
#  <Addresss: K4-16-9, Cali>,
#  <Addresss: K40-12A-13, Medellin>,
#  <Addresss: K41F-56-61, Cali>,
#  <Addresss: K45-23S-57, Bogota>,
#  <Addresss: K53-9B-45, Buga>,
#  <Addresss: K5N-38N-38, Cali>,
#  <Addresss: K6-18-2, Cali>,
#  <Addresss: K6-18-40, Cali>,
#  <Addresss: K7-21-23, Cali>,
#  <Addresss: K8-15-1, Cali>,
#  <Addresss: K81-3A-125, Cali>,
#  <Addresss: K9-11-37, Cali>,
#  <Addresss: K9-11-50, Cali>]

# %%
add.save()

# %%
add_form.is_valid()
# Out:
# False

# %%
dir(add_form)
# Out:
# ['Meta',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__html__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bound_fields_cache',
#  '_bound_items',
#  '_clean_fields',
#  '_clean_form',
#  '_errors',
#  '_get_validation_exclusions',
#  '_html_output',
#  '_meta',
#  '_post_clean',
#  '_save_m2m',
#  '_update_errors',
#  '_validate_unique',
#  '_widget_data_value',
#  'add_error',
#  'add_initial_prefix',
#  'add_prefix',
#  'as_p',
#  'as_table',
#  'as_ul',
#  'auto_id',
#  'base_fields',
#  'changed_data',
#  'clean',
#  'clean_pk',
#  'data',
#  'declared_fields',
#  'default_renderer',
#  'empty_permitted',
#  'error_class',
#  'errors',
#  'field_order',
#  'fields',
#  'files',
#  'full_clean',
#  'get_context',
#  'get_initial_for_field',
#  'has_changed',
#  'has_error',
#  'hidden_fields',
#  'initial',
#  'instance',
#  'is_bound',
#  'is_multipart',
#  'is_valid',
#  'label_suffix',
#  'media',
#  'non_field_errors',
#  'order_fields',
#  'pk_name',
#  'prefix',
#  'render',
#  'renderer',
#  'save',
#  'set_readonly_fields',
#  'template_name',
#  'template_name_label',
#  'template_name_p',
#  'template_name_table',
#  'template_name_ul',
#  'use_required_attribute',
#  'validate_unique',
#  'visible_fields']

# %%
add_form.creator = User.objects.all()[0]
add_form.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 add_form.creator = User.objects.all()[0]
# ----> 2 add_form.save()
#
# File ~/projects/adin_2022/adin/core/forms.py:8, in GenericCreateForm.save(self, *args, **kwargs)
#       7 def save(self, *args, **kwargs):
# ----> 8     base_args = {k: self.cleaned_data[k] for k in self.fields}
#       9     base_args['state_change_user'] = self.creator
#      10     obj = self._meta.model(**base_args)
#
# File ~/projects/adin_2022/adin/core/forms.py:8, in <dictcomp>(.0)
#       7 def save(self, *args, **kwargs):
# ----> 8     base_args = {k: self.cleaned_data[k] for k in self.fields}
#       9     base_args['state_change_user'] = self.creator
#      10     obj = self._meta.model(**base_args)
#
# AttributeError: 'AddressCreateModelForm' object has no attribute 'cleaned_data'

# %%
print(add_form)
# Out:
# <tr>
#     <th><label for="id_country">País:</label></th>
#     <td>
#
#       <input type="text" name="country" value="Colombia" maxlength="32" required id="id_country">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_region">Departamento:</label></th>
#     <td>
#
#       <input type="text" name="region" value="Valle del Cauca" maxlength="32" required id="id_region">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_city">Ciudad:</label></th>
#     <td>
#
#       <input type="text" name="city" value="Cali" maxlength="32" required id="id_city">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_street_type">Vía:</label></th>
#     <td>
#
#       <select name="street_type" required id="id_street_type">
#   <option value="">---------</option>
#
#   <option value="0" selected>Avenida</option>
#
#   <option value="1">Calle</option>
#
#   <option value="2">Carrera</option>
#
#   <option value="3">Diagonal</option>
#
#   <option value="4">Transversal</option>
#
#   <option value="5">Circunvalar</option>
#
#   <option value="6">Circular</option>
#
#   <option value="7">Autopista</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_street_number">Número Vía:</label></th>
#     <td>
#
#       <input type="number" name="street_number" value="6" min="0" required id="id_street_number">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_street_letter">Letra Vía:</label></th>
#     <td>
#
#       <select name="street_letter" id="id_street_letter">
#   <option value="" selected>---------</option>
#
#   <option value="0">A</option>
#
#   <option value="1">B</option>
#
#   <option value="2">C</option>
#
#   <option value="3">D</option>
#
#   <option value="4">E</option>
#
#   <option value="5">F</option>
#
#   <option value="6">G</option>
#
#   <option value="7">H</option>
#
#   <option value="8">I</option>
#
#   <option value="9">J</option>
#
#   <option value="10">K</option>
#
#   <option value="11">L</option>
#
#   <option value="12">M</option>
#
#   <option value="13">M</option>
#
#   <option value="14">O</option>
#
#   <option value="15">P</option>
#
#   <option value="16">Q</option>
#
#   <option value="17">R</option>
#
#   <option value="18">S</option>
#
#   <option value="19">T</option>
#
#   <option value="20">U</option>
#
#   <option value="21">V</option>
#
#   <option value="22">W</option>
#
#   <option value="23">X</option>
#
#   <option value="24">Y</option>
#
#   <option value="25">Z</option>
#
#   <option value="26">A1</option>
#
#   <option value="27">B1</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_street_bis">Bis Vía:</label></th>
#     <td>
#
#       <select name="street_bis" id="id_street_bis">
#   <option value="unknown">Unknown</option>
#
#   <option value="true">Yes</option>
#
#   <option value="false" selected>No</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_street_bis_complement">Letra Bis Vía:</label></th>
#     <td>
#
#       <select name="street_bis_complement" id="id_street_bis_complement">
#   <option value="" selected>---------</option>
#
#   <option value="0">A</option>
#
#   <option value="1">B</option>
#
#   <option value="2">C</option>
#
#   <option value="3">D</option>
#
#   <option value="4">E</option>
#
#   <option value="5">F</option>
#
#   <option value="6">G</option>
#
#   <option value="7">H</option>
#
#   <option value="8">I</option>
#
#   <option value="9">J</option>
#
#   <option value="10">K</option>
#
#   <option value="11">L</option>
#
#   <option value="12">M</option>
#
#   <option value="13">M</option>
#
#   <option value="14">O</option>
#
#   <option value="15">P</option>
#
#   <option value="16">Q</option>
#
#   <option value="17">R</option>
#
#   <option value="18">S</option>
#
#   <option value="19">T</option>
#
#   <option value="20">U</option>
#
#   <option value="21">V</option>
#
#   <option value="22">W</option>
#
#   <option value="23">X</option>
#
#   <option value="24">Y</option>
#
#   <option value="25">Z</option>
#
#   <option value="26">A1</option>
#
#   <option value="27">B1</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_street_coordinate">Cardinalidad Vía:</label></th>
#     <td>
#
#       <select name="street_coordinate" id="id_street_coordinate">
#   <option value="">---------</option>
#
#   <option value="0" selected>Norte</option>
#
#   <option value="1">Sur</option>
#
#   <option value="2">Este</option>
#
#   <option value="3">Oeste</option>
#
#   <option value="4">Centro</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_numeral_number">Número:</label></th>
#     <td>
#
#       <input type="number" name="numeral_number" value="13" min="0" required id="id_numeral_number">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_numeral_letter">Letra Número:</label></th>
#     <td>
#
#       <select name="numeral_letter" id="id_numeral_letter">
#   <option value="" selected>---------</option>
#
#   <option value="0">A</option>
#
#   <option value="1">B</option>
#
#   <option value="2">C</option>
#
#   <option value="3">D</option>
#
#   <option value="4">E</option>
#
#   <option value="5">F</option>
#
#   <option value="6">G</option>
#
#   <option value="7">H</option>
#
#   <option value="8">I</option>
#
#   <option value="9">J</option>
#
#   <option value="10">K</option>
#
#   <option value="11">L</option>
#
#   <option value="12">M</option>
#
#   <option value="13">M</option>
#
#   <option value="14">O</option>
#
#   <option value="15">P</option>
#
#   <option value="16">Q</option>
#
#   <option value="17">R</option>
#
#   <option value="18">S</option>
#
#   <option value="19">T</option>
#
#   <option value="20">U</option>
#
#   <option value="21">V</option>
#
#   <option value="22">W</option>
#
#   <option value="23">X</option>
#
#   <option value="24">Y</option>
#
#   <option value="25">Z</option>
#
#   <option value="26">A1</option>
#
#   <option value="27">B1</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_numeral_bis">Bis Número:</label></th>
#     <td>
#
#       <select name="numeral_bis" id="id_numeral_bis">
#   <option value="unknown">Unknown</option>
#
#   <option value="true">Yes</option>
#
#   <option value="false" selected>No</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_numeral_bis_complement">Letra Bis Número:</label></th>
#     <td>
#
#       <select name="numeral_bis_complement" id="id_numeral_bis_complement">
#   <option value="" selected>---------</option>
#
#   <option value="0">A</option>
#
#   <option value="1">B</option>
#
#   <option value="2">C</option>
#
#   <option value="3">D</option>
#
#   <option value="4">E</option>
#
#   <option value="5">F</option>
#
#   <option value="6">G</option>
#
#   <option value="7">H</option>
#
#   <option value="8">I</option>
#
#   <option value="9">J</option>
#
#   <option value="10">K</option>
#
#   <option value="11">L</option>
#
#   <option value="12">M</option>
#
#   <option value="13">M</option>
#
#   <option value="14">O</option>
#
#   <option value="15">P</option>
#
#   <option value="16">Q</option>
#
#   <option value="17">R</option>
#
#   <option value="18">S</option>
#
#   <option value="19">T</option>
#
#   <option value="20">U</option>
#
#   <option value="21">V</option>
#
#   <option value="22">W</option>
#
#   <option value="23">X</option>
#
#   <option value="24">Y</option>
#
#   <option value="25">Z</option>
#
#   <option value="26">A1</option>
#
#   <option value="27">B1</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_numeral_coordinate">Cardinalidad Número:</label></th>
#     <td>
#
#       <select name="numeral_coordinate" id="id_numeral_coordinate">
#   <option value="">---------</option>
#
#   <option value="0" selected>Norte</option>
#
#   <option value="1">Sur</option>
#
#   <option value="2">Este</option>
#
#   <option value="3">Oeste</option>
#
#   <option value="4">Centro</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_height_number">Altura Nomenclatura:</label></th>
#     <td>
#
#       <input type="number" name="height_number" value="62" min="0" required id="id_height_number">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_interior_group_type">Interior Grupo Tipo:</label></th>
#     <td>
#
#       <select name="interior_group_type" id="id_interior_group_type">
#   <option value="" selected>---------</option>
#
#   <option value="0">Bloque</option>
#
#   <option value="1">Torre</option>
#
#   <option value="2">Edificio</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_interior_group_code">Interior Grupo Código:</label></th>
#     <td>
#
#       <input type="text" name="interior_group_code" maxlength="6" id="id_interior_group_code">
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_interior_type">Interior Tipo:</label></th>
#     <td>
#
#       <select name="interior_type" id="id_interior_type">
#   <option value="" selected>---------</option>
#
#   <option value="0">Apartamento</option>
#
#   <option value="1">Local</option>
#
#   <option value="2">Oficina</option>
#
#   <option value="3">Bodega</option>
#
#   <option value="4">Parqueadero</option>
#
#   <option value="5">Depósito</option>
#
#   <option value="6">Interior</option>
#
#   <option value="7">Casa</option>
#
#   <option value="8">Lote</option>
#
#   <option value="9">Finca</option>
#
#   <option value="10">Apartaestudio</option>
#
# </select>
#
#
#     </td>
#   </tr>
#
#   <tr>
#     <th><label for="id_interior_code">Interior Código:</label></th>
#     <td>
#
#       <input type="text" name="interior_code" maxlength="6" id="id_interior_code">
#
#
#
#
#     </td>
#   </tr>
