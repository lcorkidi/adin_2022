# %%
import os
from accountables.models.lease_realty import ACCOUNT_RECEIPT_PRIORITY

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 500)

# %%
acc = Accountable.objects.get(pk='K1-17-37^2012-02-01')
acc
# Out:
# <Accountable: K1-17-37^2012-02-01>

# %%
objs_df=pd.DataFrame(Charge.objects.filter(account__in=[13802005, 13050505], concept__accountable=acc)\
                     .values('id', 'ledger', 'concept__accountable', 'account', 'account__name', 'concept__date', 'value'))
objs_df
# Out:
#       id       ledger concept__accountable   account  \
# 0   1057  FV-00000007  K1-17-37^2012-02-01  13050505
# 1   1143  FV-00000047  K1-17-37^2012-02-01  13050505
# 2   1201  FV-00000069  K1-17-37^2012-02-01  13050505
# 3   1375  FV-00000146  K1-17-37^2012-02-01  13050505
# 4   1483  FV-00000192  K1-17-37^2012-02-01  13050505
# 5   1611  FV-00000248  K1-17-37^2012-02-01  13050505
# 6   1647  FV-00000264  K1-17-37^2012-02-01  13050505
# 7   1777  FV-00000319  K1-17-37^2012-02-01  13050505
# 8   1931  FV-00000387  K1-17-37^2012-02-01  13050505
# 9   2059  FV-00000440  K1-17-37^2012-02-01  13050505
# 10  2193  FV-00000501  K1-17-37^2012-02-01  13050505
# 11    13  CA-00000007  K1-17-37^2012-02-01  13802005
# 12    93  CA-00000047  K1-17-37^2012-02-01  13802005
# 13   137  CA-00000069  K1-17-37^2012-02-01  13802005
# 14   291  CA-00000146  K1-17-37^2012-02-01  13802005
# 15   383  CA-00000192  K1-17-37^2012-02-01  13802005
# 16   495  CA-00000248  K1-17-37^2012-02-01  13802005
# 17   527  CA-00000264  K1-17-37^2012-02-01  13802005
# 18   637  CA-00000319  K1-17-37^2012-02-01  13802005
# 19   773  CA-00000387  K1-17-37^2012-02-01  13802005
# 20   879  CA-00000440  K1-17-37^2012-02-01  13802005
# 21  1001  CA-00000501  K1-17-37^2012-02-01  13802005
# 22  1055  FV-00000007  K1-17-37^2012-02-01  13802005
# 23  1056  FV-00000007  K1-17-37^2012-02-01  13802005
# 24  1141  FV-00000047  K1-17-37^2012-02-01  13802005
# 25  1142  FV-00000047  K1-17-37^2012-02-01  13802005
# 26  1199  FV-00000069  K1-17-37^2012-02-01  13802005
# 27  1200  FV-00000069  K1-17-37^2012-02-01  13802005
# 28  1373  FV-00000146  K1-17-37^2012-02-01  13802005
# 29  1374  FV-00000146  K1-17-37^2012-02-01  13802005
# 30  1481  FV-00000192  K1-17-37^2012-02-01  13802005
# 31  1482  FV-00000192  K1-17-37^2012-02-01  13802005
# 32  1609  FV-00000248  K1-17-37^2012-02-01  13802005
# 33  1610  FV-00000248  K1-17-37^2012-02-01  13802005
# 34  1645  FV-00000264  K1-17-37^2012-02-01  13802005
# 35  1646  FV-00000264  K1-17-37^2012-02-01  13802005
# 36  1775  FV-00000319  K1-17-37^2012-02-01  13802005
# 37  1776  FV-00000319  K1-17-37^2012-02-01  13802005
# 38  1929  FV-00000387  K1-17-37^2012-02-01  13802005
# 39  1930  FV-00000387  K1-17-37^2012-02-01  13802005
# 40  2057  FV-00000440  K1-17-37^2012-02-01  13802005
# 41  2058  FV-00000440  K1-17-37^2012-02-01  13802005
# 42  2191  FV-00000501  K1-17-37^2012-02-01  13802005
# 43  2192  FV-00000501  K1-17-37^2012-02-01  13802005
#
#                account__name concept__date    value
# 0        Impuesto a la Venta    2021-12-01   273600
# 1        Impuesto a la Venta    2022-01-01   273600
# 2        Impuesto a la Venta    2022-02-01   288800
# 3        Impuesto a la Venta    2022-03-01   288800
# 4        Impuesto a la Venta    2022-04-01   288800
# 5        Impuesto a la Venta    2022-05-01   288800
# 6        Impuesto a la Venta    2022-06-01   288800
# 7        Impuesto a la Venta    2022-07-01   288800
# 8        Impuesto a la Venta    2022-08-01   288800
# 9        Impuesto a la Venta    2022-09-01   288800
# 10       Impuesto a la Venta    2022-10-01   288800
# 11  Arrendamientos Inmuebles    2021-12-01  1440000
# 12  Arrendamientos Inmuebles    2022-01-01  1440000
# 13  Arrendamientos Inmuebles    2022-02-01  1520000
# 14  Arrendamientos Inmuebles    2022-03-01  1520000
# 15  Arrendamientos Inmuebles    2022-04-01  1520000
# 16  Arrendamientos Inmuebles    2022-05-01  1520000
# 17  Arrendamientos Inmuebles    2022-06-01  1520000
# 18  Arrendamientos Inmuebles    2022-07-01  1520000
# 19  Arrendamientos Inmuebles    2022-08-01  1520000
# 20  Arrendamientos Inmuebles    2022-09-01  1520000
# 21  Arrendamientos Inmuebles    2022-10-01  1520000
# 22  Arrendamientos Inmuebles    2021-12-01 -1440000
# 23  Arrendamientos Inmuebles    2021-12-01  1440000
# 24  Arrendamientos Inmuebles    2022-01-01 -1440000
# 25  Arrendamientos Inmuebles    2022-01-01  1440000
# 26  Arrendamientos Inmuebles    2022-02-01 -1520000
# 27  Arrendamientos Inmuebles    2022-02-01  1520000
# 28  Arrendamientos Inmuebles    2022-03-01 -1520000
# 29  Arrendamientos Inmuebles    2022-03-01  1520000
# 30  Arrendamientos Inmuebles    2022-04-01 -1520000
# 31  Arrendamientos Inmuebles    2022-04-01  1520000
# 32  Arrendamientos Inmuebles    2022-05-01 -1520000
# 33  Arrendamientos Inmuebles    2022-05-01  1520000
# 34  Arrendamientos Inmuebles    2022-06-01 -1520000
# 35  Arrendamientos Inmuebles    2022-06-01  1520000
# 36  Arrendamientos Inmuebles    2022-07-01 -1520000
# 37  Arrendamientos Inmuebles    2022-07-01  1520000
# 38  Arrendamientos Inmuebles    2022-08-01 -1520000
# 39  Arrendamientos Inmuebles    2022-08-01  1520000
# 40  Arrendamientos Inmuebles    2022-09-01 -1520000
# 41  Arrendamientos Inmuebles    2022-09-01  1520000
# 42  Arrendamientos Inmuebles    2022-10-01 -1520000
# 43  Arrendamientos Inmuebles    2022-10-01  1520000

# %%
def GetChargeDue(charge_id):
    cha=Charge.objects.get(pk=charge_id)
    if cha.ledger.type.abreviation == 'CA':
        if Charge.objects.filter(account=cha.account, concept=cha.concept, ledger__type__abreviation='FV', value=-cha.value).exists():
            return 0
    elif cha.ledger.type.abreviation == 'FV' and cha.value < 0:
        if Charge.objects.filter(account=cha.account, concept=cha.concept, ledger__type__abreviation='CA', value=-cha.value).exists():
            return 0        
    elif cha.ledger.type.abreviation == 'FV' and cha.value > 0:
        receipt = Charge.objects.filter(account=cha.account, concept=cha.concept, ledger__type__abreviation='RC', value__gt=0).aggregate(receipt=Sum('value'))['receipt']
        return cha.value + receipt if receipt else cha.value
    else:
        return 0

# %%
def DueAge(_dueDate):
    bufferDate=_dueDate
    months=0
    days=0
    while bufferDate < datetime.date.today():
        if bufferDate + relativedelta(months=1) < datetime.date.today():
            months = months +1
        else:
            days=(datetime.date.today() - bufferDate).days
        bufferDate = bufferDate + relativedelta(months=1)
    return f'{months}, {days}'

# %%
due_df=objs_df.assign(
    due_value=objs_df.id.apply(lambda x: GetChargeDue(x)),
    due_age=objs_df.concept__date.apply(lambda x: DueAge(x)))
due_df
# Out:
#       id       ledger concept__accountable             account__name  \
# 0     13  CA-00000007  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 1   1056  FV-00000007  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 2   1057  FV-00000007  K1-17-37^2012-02-01       Impuesto a la Venta
# 3   1055  FV-00000007  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 4     93  CA-00000047  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 5   1142  FV-00000047  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 6   1143  FV-00000047  K1-17-37^2012-02-01       Impuesto a la Venta
# 7   1141  FV-00000047  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 8    137  CA-00000069  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 9   1200  FV-00000069  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 10  1201  FV-00000069  K1-17-37^2012-02-01       Impuesto a la Venta
# 11  1199  FV-00000069  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 12   291  CA-00000146  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 13  1374  FV-00000146  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 14  1375  FV-00000146  K1-17-37^2012-02-01       Impuesto a la Venta
# 15  1373  FV-00000146  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 16   383  CA-00000192  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 17  1482  FV-00000192  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 18  1483  FV-00000192  K1-17-37^2012-02-01       Impuesto a la Venta
# 19  1481  FV-00000192  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 20   495  CA-00000248  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 21  1610  FV-00000248  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 22  1611  FV-00000248  K1-17-37^2012-02-01       Impuesto a la Venta
# 23  1609  FV-00000248  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 24   527  CA-00000264  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 25  1646  FV-00000264  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 26  1647  FV-00000264  K1-17-37^2012-02-01       Impuesto a la Venta
# 27  1645  FV-00000264  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 28   637  CA-00000319  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 29  1776  FV-00000319  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 30  1777  FV-00000319  K1-17-37^2012-02-01       Impuesto a la Venta
# 31  1775  FV-00000319  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 32   773  CA-00000387  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 33  1930  FV-00000387  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 34  1931  FV-00000387  K1-17-37^2012-02-01       Impuesto a la Venta
# 35  1929  FV-00000387  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 36   879  CA-00000440  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 37  2058  FV-00000440  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 38  2059  FV-00000440  K1-17-37^2012-02-01       Impuesto a la Venta
# 39  2057  FV-00000440  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 40  1001  CA-00000501  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 41  2192  FV-00000501  K1-17-37^2012-02-01  Arrendamientos Inmuebles
# 42  2193  FV-00000501  K1-17-37^2012-02-01       Impuesto a la Venta
# 43  2191  FV-00000501  K1-17-37^2012-02-01  Arrendamientos Inmuebles
#
#    concept__date    value  due_value due_age
# 0     2021-12-01  1440000          0  10, 31
# 1     2021-12-01  1440000    1440000  10, 31
# 2     2021-12-01   273600     273600  10, 31
# 3     2021-12-01 -1440000          0  10, 31
# 4     2022-01-01  1440000          0   9, 31
# 5     2022-01-01  1440000    1440000   9, 31
# 6     2022-01-01   273600     273600   9, 31
# 7     2022-01-01 -1440000          0   9, 31
# 8     2022-02-01  1520000          0   8, 31
# 9     2022-02-01  1520000    1520000   8, 31
# 10    2022-02-01   288800     288800   8, 31
# 11    2022-02-01 -1520000          0   8, 31
# 12    2022-03-01  1520000          0   7, 31
# 13    2022-03-01  1520000    1520000   7, 31
# 14    2022-03-01   288800     288800   7, 31
# 15    2022-03-01 -1520000          0   7, 31
# 16    2022-04-01  1520000          0   6, 31
# 17    2022-04-01  1520000    1520000   6, 31
# 18    2022-04-01   288800     288800   6, 31
# 19    2022-04-01 -1520000          0   6, 31
# 20    2022-05-01  1520000          0   5, 31
# 21    2022-05-01  1520000    1520000   5, 31
# 22    2022-05-01   288800     288800   5, 31
# 23    2022-05-01 -1520000          0   5, 31
# 24    2022-06-01  1520000          0   4, 31
# 25    2022-06-01  1520000    1520000   4, 31
# 26    2022-06-01   288800     288800   4, 31
# 27    2022-06-01 -1520000          0   4, 31
# 28    2022-07-01  1520000          0   3, 31
# 29    2022-07-01  1520000    1520000   3, 31
# 30    2022-07-01   288800     288800   3, 31
# 31    2022-07-01 -1520000          0   3, 31
# 32    2022-08-01  1520000          0   2, 31
# 33    2022-08-01  1520000    1520000   2, 31
# 34    2022-08-01   288800     288800   2, 31
# 35    2022-08-01 -1520000          0   2, 31
# 36    2022-09-01  1520000          0   1, 31
# 37    2022-09-01  1520000    1520000   1, 31
# 38    2022-09-01   288800     288800   1, 31
# 39    2022-09-01 -1520000          0   1, 31
# 40    2022-10-01  1520000          0   0, 31
# 41    2022-10-01  1520000    1520000   0, 31
# 42    2022-10-01   288800     288800   0, 31
# 43    2022-10-01 -1520000          0   0, 31

# %%
pending_df = due_df[due_df['due_value'] != 0].to_dict('records')
pending_df
# Out:
# [{'id': 1056,
#   'ledger': 'FV-00000007',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2021, 12, 1),
#   'value': 1440000,
#   'due_value': 1440000,
#   'due_age': '10, 31'},
#  {'id': 1057,
#   'ledger': 'FV-00000007',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2021, 12, 1),
#   'value': 273600,
#   'due_value': 273600,
#   'due_age': '10, 31'},
#  {'id': 1142,
#   'ledger': 'FV-00000047',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 1, 1),
#   'value': 1440000,
#   'due_value': 1440000,
#   'due_age': '9, 31'},
#  {'id': 1143,
#   'ledger': 'FV-00000047',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 1, 1),
#   'value': 273600,
#   'due_value': 273600,
#   'due_age': '9, 31'},
#  {'id': 1200,
#   'ledger': 'FV-00000069',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 2, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '8, 31'},
#  {'id': 1201,
#   'ledger': 'FV-00000069',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 2, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '8, 31'},
#  {'id': 1374,
#   'ledger': 'FV-00000146',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 3, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '7, 31'},
#  {'id': 1375,
#   'ledger': 'FV-00000146',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 3, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '7, 31'},
#  {'id': 1482,
#   'ledger': 'FV-00000192',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 4, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '6, 31'},
#  {'id': 1483,
#   'ledger': 'FV-00000192',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 4, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '6, 31'},
#  {'id': 1610,
#   'ledger': 'FV-00000248',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 5, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '5, 31'},
#  {'id': 1611,
#   'ledger': 'FV-00000248',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 5, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '5, 31'},
#  {'id': 1646,
#   'ledger': 'FV-00000264',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 6, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '4, 31'},
#  {'id': 1647,
#   'ledger': 'FV-00000264',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 6, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '4, 31'},
#  {'id': 1776,
#   'ledger': 'FV-00000319',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 7, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '3, 31'},
#  {'id': 1777,
#   'ledger': 'FV-00000319',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 7, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '3, 31'},
#  {'id': 1930,
#   'ledger': 'FV-00000387',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 8, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '2, 31'},
#  {'id': 1931,
#   'ledger': 'FV-00000387',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 8, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '2, 31'},
#  {'id': 2058,
#   'ledger': 'FV-00000440',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 9, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '1, 31'},
#  {'id': 2059,
#   'ledger': 'FV-00000440',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 9, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '1, 31'},
#  {'id': 2192,
#   'ledger': 'FV-00000501',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 10, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '0, 31'},
#  {'id': 2193,
#   'ledger': 'FV-00000501',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 10, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '0, 31'}]

# %%
pending_df.to_dict('records')
# Out:
# [{'id': 1056,
#   'ledger': 'FV-00000007',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2021, 12, 1),
#   'value': 1440000,
#   'due_value': 1440000,
#   'due_age': '10, 31'},
#  {'id': 1057,
#   'ledger': 'FV-00000007',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2021, 12, 1),
#   'value': 273600,
#   'due_value': 273600,
#   'due_age': '10, 31'},
#  {'id': 1142,
#   'ledger': 'FV-00000047',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 1, 1),
#   'value': 1440000,
#   'due_value': 1440000,
#   'due_age': '9, 31'},
#  {'id': 1143,
#   'ledger': 'FV-00000047',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 1, 1),
#   'value': 273600,
#   'due_value': 273600,
#   'due_age': '9, 31'},
#  {'id': 1200,
#   'ledger': 'FV-00000069',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 2, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '8, 31'},
#  {'id': 1201,
#   'ledger': 'FV-00000069',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 2, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '8, 31'},
#  {'id': 1374,
#   'ledger': 'FV-00000146',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 3, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '7, 31'},
#  {'id': 1375,
#   'ledger': 'FV-00000146',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 3, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '7, 31'},
#  {'id': 1482,
#   'ledger': 'FV-00000192',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 4, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '6, 31'},
#  {'id': 1483,
#   'ledger': 'FV-00000192',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 4, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '6, 31'},
#  {'id': 1610,
#   'ledger': 'FV-00000248',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 5, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '5, 31'},
#  {'id': 1611,
#   'ledger': 'FV-00000248',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 5, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '5, 31'},
#  {'id': 1646,
#   'ledger': 'FV-00000264',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 6, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '4, 31'},
#  {'id': 1647,
#   'ledger': 'FV-00000264',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 6, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '4, 31'},
#  {'id': 1776,
#   'ledger': 'FV-00000319',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 7, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '3, 31'},
#  {'id': 1777,
#   'ledger': 'FV-00000319',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 7, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '3, 31'},
#  {'id': 1930,
#   'ledger': 'FV-00000387',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 8, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '2, 31'},
#  {'id': 1931,
#   'ledger': 'FV-00000387',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 8, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '2, 31'},
#  {'id': 2058,
#   'ledger': 'FV-00000440',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 9, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '1, 31'},
#  {'id': 2059,
#   'ledger': 'FV-00000440',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 9, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '1, 31'},
#  {'id': 2192,
#   'ledger': 'FV-00000501',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Arrendamientos Inmuebles',
#   'concept__date': datetime.date(2022, 10, 1),
#   'value': 1520000,
#   'due_value': 1520000,
#   'due_age': '0, 31'},
#  {'id': 2193,
#   'ledger': 'FV-00000501',
#   'concept__accountable': 'K1-17-37^2012-02-01',
#   'account__name': 'Impuesto a la Venta',
#   'concept__date': datetime.date(2022, 10, 1),
#   'value': 288800,
#   'due_value': 288800,
#   'due_age': '0, 31'}]
