# %%
import os
from os.path import join
from adin.settings import BASE_DIR

from adin.utils.date_progression import nextmonthlydate, nextyearlydate, previousmonthlydate, previousyearlydate

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 500)

# %%
cls = Lease_Realty

# %%
objs_df = pd.DataFrame(cls.objects.values()).drop(['state_change_user_id', 'state_change_date', 'state', 'subclass_id'], axis=1)
errors_report=objs_df.assign(errors=objs_df[f'{cls._meta.pk.name}_id'].apply(lambda x: eval(f'cls.objects.get(pk=x).{cls._meta.pk.name}.get_obj_errors()'))).drop('accountable_ptr_id', axis=1)
errors_report
# Out:
#                           code    doc_date  start_date    end_date errors
# 0     A6N-13N-62-O1^2015-01-01  2015-01-01  2022-01-01        None     []
# 1   A6N-13N-62-S101^2021-04-01  2021-04-01  2022-01-01        None     []
# 2   A6N-13N-62-S102^2021-10-01  2021-10-01  2022-01-01        None     []
# 3   A6N-13N-62-S103^2020-06-01  2020-06-01  2022-01-01  2022-04-30     []
# 4   A6N-13N-62-S103^2022-05-01  2022-05-01  2022-05-01        None     []
# 5   A6N-13N-62-S104^2021-08-01  2021-08-01  2022-01-01        None     []
# 6   A6N-13N-62-S105^2021-09-01  2021-09-01  2022-01-01        None     []
# 7   A6N-13N-62-S108^2016-12-01  2016-12-01  2022-01-01        None     []
# 8   A6N-13N-62-S109^2021-07-01  2021-07-01  2022-01-01        None     []
# 9   A6N-13N-62-S110^2021-09-01  2021-09-01  2022-01-01        None     []
# 10  A6N-13N-62-S111^2021-04-01  2021-04-01  2022-01-01  2022-03-31     []
# 11  A6N-13N-62-S111^2022-07-01  2022-07-01  2022-06-25        None     []
# 12  A6N-13N-62-S112^2015-04-01  2015-04-01  2022-01-01        None     []
# 13  A6N-13N-62-S114^2021-09-01  2021-09-01  2022-01-01        None     []
# 14  A6N-13N-62-S201^2021-10-01  2021-10-01  2022-01-01        None     []
# 15  A6N-13N-62-S202^2021-10-01  2021-10-01  2022-01-01        None     []
# 16  A6N-13N-62-S203^2020-10-01  2020-10-01  2022-01-01  2022-01-31     []
# 17  A6N-13N-62-S203^2022-04-01  2022-04-01  2022-04-01        None     []
# 18  A6N-13N-62-S204^2021-09-01  2021-09-01  2022-01-01        None     []
# 19  A6N-13N-62-S205^2020-08-01  2020-08-01  2022-01-01        None     []
# 20  A6N-13N-62-S207^2004-03-01  2004-03-01  2022-01-01  2022-03-31     []
# 21  A6N-13N-62-S208^2021-10-01  2021-10-01  2022-01-01        None     []
# 22  A6N-13N-62-S209^2006-03-21  2006-03-21  2021-12-21        None     []
# 23  A6N-13N-62-S210^2017-03-20  2017-03-20  2021-12-20  2022-03-19     []
# 24  A6N-13N-62-S211^2017-03-08  2017-03-08  2022-01-08        None     []
# 25  A6N-13N-62-S212^2011-09-01  2011-09-01  2022-01-01        None     []
# 26  A6N-13N-62-S214^2018-10-01  2018-10-01  2022-01-01        None     []
# 27  A6N-13N-62-S217^2018-12-01  2018-12-01  2021-11-01        None     []
# 28  A6N-13N-62-S219^2004-02-09  2004-02-09  2022-01-09        None     []
# 29  A6N-13N-62-S221^2018-06-15  2018-06-15  2022-01-15        None  [137]
# 30  A6N-13N-62-S222^2022-06-01  2022-06-01  2022-06-01        None     []
# 31  A6N-13N-62-S301^2021-08-01  2021-08-01  2022-01-01  2022-07-31     []
# 32  A6N-13N-62-S302^2021-08-01  2021-08-01  2021-12-01        None     []
# 33  A6N-13N-62-S303^2022-03-01  2022-03-01  2022-02-07        None     []
# 34  A6N-13N-62-S304^2022-04-01  2022-04-01  2022-04-01        None     []
# 35  A6N-13N-62-S305^2021-02-01  2021-02-01  2022-01-01        None     []
# 36  A6N-13N-62-S306^2018-06-01  2018-06-01  2021-11-01        None     []
# 37  A6N-13N-62-S308^2022-03-01  2022-03-01  2022-03-01  2022-05-31     []
# 38  A6N-13N-62-S308^2022-07-01  2022-07-01  2022-07-01        None     []
# 39  A6N-13N-62-S309^2022-03-01  2022-03-01  2022-03-01        None     []
# 40  A6N-13N-62-S310^2021-12-01  2021-12-01  2022-01-01  2022-01-31     []
# 41  A6N-13N-62-S310^2022-07-01  2022-07-01  2022-07-01        None     []
# 42  A6N-13N-62-S311^2021-11-01  2021-11-01  2022-01-01        None     []
# 43  A6N-13N-62-S312^2017-06-01  2017-06-01  2022-01-01        None     []
# 44  A6N-13N-62-S314^2019-06-01  2019-06-01  2022-01-01        None     []
# 45  A6N-13N-62-S315^2019-08-01  2019-08-01  2022-01-01  2022-06-30     []
# 46  A6N-13N-62-S317^2022-06-01  2022-06-01  2022-06-03        None     []
# 47  A6N-13N-62-S318^2021-08-01  2021-08-01  2022-01-01        None     []
# 48  A6N-13N-62-S319^2021-08-01  2021-08-01  2022-01-01        None     []
# 49  A6N-13N-62-S321^1996-08-13  1996-08-13  2022-01-13        None     []
# 50  A6N-13N-62-S322^2021-01-01  2021-01-01  2022-01-01        None     []
# 51       A6N-13N-66^2019-04-01  2019-04-01  2022-01-01        None     []
# 52       A6N-13N-68^1999-02-01  1999-02-01  2022-01-01        None     []

# %%
errors_report.to_csv(join(BASE_DIR, f'_files/reports/{datetime.date.today().strftime("%Y-%m-%d")}_lease_realty_errors.csv'), float_format='%.0f', na_rep=None, index=False)

# %%
lea_rea_con_data = pd.read_csv(join(BASE_DIR, f"_files/lea_rea_con_data.csv"), keep_default_na=False)
lea_rea_con_data

# %%
lea_rea_merged=errors_report.merge(lea_rea_con_data[['pk', 'first_concept_date']], left_on='code', right_on='pk').drop('pk', axis=1)
lea_rea_merged

# %%
pending_date_values=lea_rea_merged\
    .assign(pending_concept_date_value_dict=lea_rea_merged.apply(lambda x: Lease_Realty.objects.get(pk=x.code).pending_concept_date_value_dict(datetime.date(*[int(i) for i in x.first_concept_date.split('-')]) if x.first_concept_date else None), axis=1))
pending_date_values

# %%
pending_dates=lea_rea_merged\
    .assign(pending_accountable_concept_dates=lea_rea_merged.apply(lambda x: Lease_Realty.objects.get(pk=x.code).pending_accountable_concept_dates(datetime.date(*[int(i) for i in x.first_concept_date.split('-')]) if x.first_concept_date else None), axis=1))\
    .assign(pending_accountable_concept_dates=lea_rea_merged.apply(lambda x: Lease_Realty.objects.get(pk=x.code).pending_date_value_dates(datetime.date(*[int(i) for i in x.first_concept_date.split('-')]) if x.first_concept_date else None), axis=1))
pending_dates

# %%
def get_value4date(obj, date):
    if not obj.end_date or obj.end_date >= nextmonthlydate(obj.doc_date, date):
        return int(round(((nextmonthlydate(obj.doc_date, date) - date).days / (nextmonthlydate(obj.doc_date, date) - previousmonthlydate(obj.doc_date, date)).days) * int(obj.date_value.filter(date__lte=item).latest('date').value), 0))
    else:
        return int(round(((obj.end_date - previousmonthlydate(obj.doc_date, date)).days / (nextmonthlydate(obj.doc_date, date) - previousmonthlydate(obj.doc_date, date)).days) * int(obj.date_value.filter(date__lte=item).latest('date').value), 0))

# %%
def pending_date_value_dict(obj, ref_date=None):
    date_value_dict = {}
    for item in obj.pending_accountable_concept_dates(ref_date):
        if obj.date_value.filter(date__lte=item).exists() and obj.date_value.filter(date__lte=item).latest('date').date >= previousyearlydate(obj.doc_date, item):
            date_value_dict[item] = get_value4date(obj, item)        
        else:
            date_value_dict[item] = None        
    return date_value_dict

# %%
pending_dates.assign(concept_values=pending_dates.apply(lambda x: get_date_value_dict(Lease_Realty.objects.get(pk=x.code), datetime.date(*[int(dt) for dt in x.first_concept_date.split('-')]) if x.first_concept_date else None), axis=1))
# Out:
#                           code    doc_date  start_date end_date  \
# 0         C18-1N-41^2021-02-01  2021-02-01  2021-02-01     None
# 1          K1-17-43^2017-07-15  2017-07-15        None     None
# 2          K1-17-37^2012-02-01  2012-02-01        None     None
# 3         C18-1N-39^2022-03-01  2022-03-01  2022-03-11     None
# 4         C18-1N-33^2021-10-01  2021-10-01  2021-10-01     None
# 5          K1-17-53^2017-06-01  2017-06-01  2017-06-01     None
# 6          K1-17-57^2001-09-01  2001-09-01  2001-09-01     None
# 7          K1-17-47^2021-10-01  2021-10-01  2021-10-01     None
# 8         C31-1B-74^2012-12-07  2012-12-07  2012-12-01     None
# 9         C31-1B-64^2018-12-01  2018-12-01  2018-12-01     None
# 10        C31-1B-24^2016-02-15  2016-02-15        None     None
# 11        C31-1B-54^2016-02-15  2016-02-15  2016-02-15     None
# 12        C31-1B-44^2013-12-03  2013-12-03  2013-12-03     None
# 13         C31-1B-4^2009-01-01  2009-01-01  2009-01-01     None
# 14     K2C-30-15-B2^2019-07-01  2019-07-01  2019-07-01     None
# 15        C31-1B-34^2004-08-01  2004-08-01  2004-08-01     None
# 16        C31-1B-24^2018-05-01  2018-05-01  2018-05-01     None
# 17        K1B-30-52^1970-01-01  1970-01-01        None     None
# 18        K1B-30-52^2018-05-01  2018-05-01  2018-05-01     None
# 19        K2C-30-29^2019-11-01  2019-11-01  2019-11-01     None
# 20        K2C-30-27^2020-10-01  2020-10-01  2020-10-01     None
# 21        C30-1B-31^2019-11-01  2019-11-01  2019-11-01     None
# 22        C30-1B-27^2014-09-01  2014-09-01  2014-09-01     None
# 23     C30-1B-15-B3^2017-10-01  2017-10-01        None     None
# 24     C30-1B-15-B2^2013-04-15  2013-04-15  2013-04-15     None
# 25     C30-1B-15-B1^2020-11-01  2020-11-01  2020-11-01     None
# 26        K2C-30-51^2021-12-01  2021-12-01  2021-12-15     None
# 27     C30-1B-15-B5^2019-04-01  2019-04-01  2019-04-01     None
# 69  A6N-13N-62-S311^2021-11-01  2021-11-01  2021-11-01     None
# 70  A6N-13N-62-S312^2007-06-01  2007-06-01  2007-06-01     None
# 71  A6N-13N-62-S314^2019-06-01  2019-06-01  2019-06-01     None
#
#              errors first_concept_date  \
# 0        [135, 139]
# 1             [139]
# 2        [135, 139]
# 3        [135, 139]
# 4             [139]
# 5             [139]
# 6             [139]
# 7        [135, 139]
# 8             [139]
# 9             [139]
# 10  [135, 137, 139]
# 11            [139]
# 12            [139]
# 13       [137, 139]
# 14            [139]
# 15            [139]
# 16            [139]
# 17  [135, 137, 139]
# 18            [139]
# 19            [139]
# 20            [139]
# 21            [139]
# 22            [139]
# 23       [135, 139]
# 24            [139]
# 25            [139]
# 26            [139]
# 27            [139]
# 28            [139]
# 29            [139]
# 30            [139]
# 31            [139]
# 32            [139]
# 33            [139]
# 34            [139]         2022-01-01
# 35            [139]         2022-01-01
# 36            [139]         2022-01-01
# 37            [139]         2022-01-01
# 38            [139]         2022-01-01
# 39            [139]         2022-01-01
# 40            [139]
# 41            [139]
# 42       [137, 139]         2022-01-01
# 43            [139]         2022-01-01
# 44            [139]         2022-01-01
# 45            [139]         2022-01-01
# 46            [139]         2022-01-01
# 47            [139]         2022-01-01
# 48            [139]         2022-04-01
# 49            [139]         2022-01-01
# 50            [139]
# 51            [139]         2022-01-01
# 52            [139]         2022-01-01
# 53            [139]         2021-12-21
# 54            [139]         2021-12-20
# 55            [139]
# 56            [139]         2022-01-01
# 57            [139]         2022-01-01
# 58            [139]         2021-11-01
# 59            [139]         2022-01-01
# 60       [137, 139]         2022-01-15
# 61            [139]         2022-01-01
# 62            [139]         2021-12-01
# 63            [139]         2022-02-07
# 64            [139]         2022-04-01
# 65            [139]         2021-01-01
# 66            [139]         2021-11-01
# 67            [139]         2022-03-01
# 68            [139]         2022-03-01
# 69            [139]         2022-01-01
# 70            [139]         2022-01-01
# 71            [139]         2022-01-01
#
#                     pending_accountable_concept_dates  \
# 0   [2021-02-01, 2021-03-01, 2021-04-01, 2021-05-0...
# 1                                                  []
# 2                                                  []
# 3   [2022-03-11, 2022-04-01, 2022-05-01, 2022-06-0...
# 4   [2021-10-01, 2021-11-01, 2021-12-01, 2022-01-0...
# 5   [2017-06-01, 2017-07-01, 2017-08-01, 2017-09-0...
# 6   [2001-09-01, 2001-10-01, 2001-11-01, 2001-12-0...
# 7   [2021-10-01, 2021-11-01, 2021-12-01, 2022-01-0...
# 8   [2012-12-01, 2012-12-07, 2013-01-07, 2013-02-0...
# 9   [2018-12-01, 2019-01-01, 2019-02-01, 2019-03-0...
# 10                                                 []
# 11  [2016-02-15, 2016-03-15, 2016-04-15, 2016-05-1...
# 12  [2013-12-03, 2014-01-03, 2014-02-03, 2014-03-0...
# 13  [2009-01-01, 2009-02-01, 2009-03-01, 2009-04-0...
# 14  [2019-07-01, 2019-08-01, 2019-09-01, 2019-10-0...
# 15  [2004-08-01, 2004-09-01, 2004-10-01, 2004-11-0...
# 16  [2018-05-01, 2018-06-01, 2018-07-01, 2018-08-0...
# 17                                                 []
# 18  [2018-05-01, 2018-06-01, 2018-07-01, 2018-08-0...
# 53  {2021-12-21: None, 2022-01-21: None, 2022-02-2...
# 54  {2021-12-20: None, 2022-01-20: None, 2022-02-2...
# 55  {2017-03-20: 467000, 2017-04-20: 467000, 2017-...
# 56  {2022-01-01: None, 2022-02-01: None, 2022-03-0...
# 57  {2022-01-01: None, 2022-02-01: None, 2022-03-0...
# 58  {2021-11-01: None, 2021-12-01: None, 2022-01-0...
# 59  {2022-01-01: None, 2022-01-09: None, 2022-02-0...
# 60  {2022-01-15: None, 2022-02-15: None, 2022-03-1...
# 61  {2022-01-01: 830000, 2022-02-01: 830000, 2022-...
# 62  {2021-12-01: 700000, 2022-01-01: 700000, 2022-...
# 63  {2022-02-07: None, 2022-03-01: 700000, 2022-04...
# 64  {2022-04-01: 700000, 2022-05-01: 700000, 2022-...
# 65  {2021-01-01: None, 2021-02-01: 850000, 2021-03...
# 66  {2021-11-01: None, 2021-12-01: None, 2022-01-0...
# 67  {2022-03-01: 390000, 2022-04-01: 390000, 2022-...
# 68  {2022-03-01: 390000, 2022-04-01: 390000, 2022-...
# 69  {2022-01-01: 390000, 2022-02-01: 390000, 2022-...
# 70  {2022-01-01: None, 2022-02-01: None, 2022-03-0...
# 71  {2022-01-01: None, 2022-02-01: None, 2022-03-0...

# %%
obj = cls.objects.get(pk='A6N-13N-62-S101^2021-04-01')
obj
# Out:
# <Lease_Realty: A6N-13N-62-S101^2021-04-01>

# %%
obj.pending_date_values_dates()
# Out:
# []

# %%
accon=Accountable_Concept.objects.get(accountable=obj, date=dt)
accon.state
# Out:
# 1

# %%
def monthly_dates(self, first_date=None):
    date_list = []
    if not self.start_date:
        return date_list
    elif first_date:
        ref_date = first_date
    else:
        ref_date = self.start_date
    if self.end_date and self.end_date <= datetime.date.today():
        end_date = self.end_date
    else:
        end_date = datetime.date.today()
    while ref_date <= end_date:
        date_list.append(ref_date)
        ref_date = nextmonthlydate(self.doc_date, ref_date)
    return date_list

# %%
def yearly_dates(self, first_date=None):
    date_list = []
    if not self.start_date:
        return date_list
    elif first_date:
        ref_date = previousyearlydate(self.doc_date, first_date)
    else:
        ref_date = self.doc_date
    if self.end_date and self.end_date <= datetime.date.today():
        end_date = self.end_date
    else:
        end_date = datetime.date.today() + relativedelta(months=3)
    while ref_date < end_date:
        date_list.append(ref_date)
        ref_date = ref_date + relativedelta(years=1)
    return date_list

# %%
def get_value_4_date(self, date):
    if not self.end_date or self.end_date >= nextmonthlydate(self.doc_date, date):
        return int(round(((nextmonthlydate(self.doc_date, date) - date).days / (nextmonthlydate(self.doc_date, date) - previousmonthlydate(self.doc_date, date)).days) * int(self.date_value.filter(date__lte=date).latest('date').value), 0))
    else:
        return int(round(((self.end_date - previousmonthlydate(self.doc_date, date)).days / (nextmonthlydate(self.doc_date, date) - previousmonthlydate(self.doc_date, date)).days) * int(self.date_value.filter(date__lte=date).latest('date').value), 0))

# %%
def pending_concept_dates(self, first_date=None):
    if not self.start_date:
        return []
    concept_dates = [item['date'] for item in self.accountable_concept.exclude(state=0).values('date')]
    return [dt for dt in monthly_dates(self, first_date) if dt not in concept_dates and dt < min(pending_date_values_dates(self, first_date))]

# %%
def pending_date_values_dates(self, first_date=None):
    if not self.start_date:
        return []
    date_values_dates = [item['date'] for item in self.date_value.exclude(state=0).values('date')]
    return [dt for dt in yearly_dates(self, first_date) if dt not in date_values_dates]

# %%
def pending_concept_date_values(self, first_date=None):
    if not self.start_date:
        return {}
    pending_dates = pending_concept_dates(self, first_date)
    return {dt: get_value_4_date(self, dt) for dt in pending_dates}

# %%
pending_concept_dates(obj)
# Out:
# [datetime.date(2018, 11, 1),
#  datetime.date(2018, 12, 1),
#  datetime.date(2019, 1, 1),
#  datetime.date(2019, 2, 1),
#  datetime.date(2019, 3, 1),
#  datetime.date(2019, 4, 1),
#  datetime.date(2019, 5, 1),
#  datetime.date(2019, 6, 1),
#  datetime.date(2019, 7, 1),
#  datetime.date(2019, 8, 1),
#  datetime.date(2019, 9, 1),
#  datetime.date(2019, 10, 1),
#  datetime.date(2019, 11, 1),
#  datetime.date(2019, 12, 1),
#  datetime.date(2020, 1, 1),
#  datetime.date(2020, 2, 1),
#  datetime.date(2020, 3, 1),
#  datetime.date(2020, 4, 1),
#  datetime.date(2020, 5, 1),
#  datetime.date(2020, 6, 1),
#  datetime.date(2020, 7, 1),
#  datetime.date(2020, 8, 1),
#  datetime.date(2020, 9, 1)]

# %%
ref_date=None

# %%
obj.pending_accountable_concept_dates(ref_date)
# Out:
# [datetime.date(2022, 3, 11),
#  datetime.date(2022, 4, 1),
#  datetime.date(2022, 5, 1),
#  datetime.date(2022, 6, 1),
#  datetime.date(2022, 7, 1),
#  datetime.date(2022, 8, 1)]

# %%
values = []
for item in obj.pending_accountable_concept_dates(ref_date):
    if not obj.date_value.filter(date__lte=item).exists():
        values.append(None)
    elif obj.date_value.filter(date__lte=item).latest('date').date >= previousyearlydate(obj.doc_date, item):
        values.append(obj.date_value.filter(date__lte=item).latest('date').value)
    else:
        values.append(None)
values
# Out:
# [1000000, 1000000, 1000000, 1000000, 1000000, 1000000]

# %%
realties_pending=pd.DataFrame(Realty.objects.values('pk','lease_realty'))\
    .rename(columns={'pk':'realty'})
realties_pending
# Out:
#              realty                lease_realty
# 0     A6N-13N-62-O1                        None
# 1   A6N-13N-62-S101  A6N-13N-62-S101^2021-04-01
# 2   A6N-13N-62-S102  A6N-13N-62-S102^2021-10-01
# 3   A6N-13N-62-S103  A6N-13N-62-S103^2020-06-01
# 4   A6N-13N-62-S104  A6N-13N-62-S104^2021-08-01
# 5   A6N-13N-62-S105  A6N-13N-62-S105^2021-09-01
# 6   A6N-13N-62-S106                        None
# 7   A6N-13N-62-S107                        None
# 8   A6N-13N-62-S108  A6N-13N-62-S108^2016-12-01
# 9   A6N-13N-62-S109  A6N-13N-62-S109^2021-07-01
# 10  A6N-13N-62-S110  A6N-13N-62-S110^2021-09-01
# 11  A6N-13N-62-S111                        None
# 12  A6N-13N-62-S112                        None
# 13  A6N-13N-62-S114  A6N-13N-62-S114^2021-09-01
# 14  A6N-13N-62-S201  A6N-13N-62-S201^2021-10-01
# 15  A6N-13N-62-S202  A6N-13N-62-S202^2021-10-01
# 16  A6N-13N-62-S203  A6N-13N-62-S203^2022-04-01
# 73        C31-1B-44        C31-1B-44^2013-12-03
# 74        C31-1B-54        C31-1B-54^2016-02-15
# 75        C31-1B-64        C31-1B-64^2018-12-01
# 76        C31-1B-74        C31-1B-74^2012-12-07
# 77        C31-1B-80        C31-1B-80^2013-06-01
# 78         K1-17-37         K1-17-37^2012-02-01
# 79         K1-17-43         K1-17-43^2017-07-15
# 80         K1-17-47         K1-17-47^2021-10-01
# 81         K1-17-53         K1-17-53^2017-06-01
# 82         K1-17-57         K1-17-57^2001-09-01
# 83         K1-17-65                        None
# 84     K1-35-29-B11     K1-35-29-B11^2020-08-01
# 85      K1-35-29-B9      K1-35-29-B9^2021-09-01
# 86        K1B-30-16        K1B-30-16^2006-05-10
# 87        K1B-30-34        K1B-30-34^2013-09-01
# 88        K1B-30-52        K1B-30-52^1970-01-01
# 89        K1B-30-52        K1B-30-52^2018-05-01
# 90        K1B-30-76                        None
# 91        K2C-29-36        K2C-29-36^2017-04-01
# 92     K2C-30-15-B2     K2C-30-15-B2^2019-07-01
# 93     K2C-30-15-B3     K2C-30-15-B3^2013-06-01
# 94        K2C-30-27        K2C-30-27^2020-10-01
# 95        K2C-30-29        K2C-30-29^2019-11-01
# 96         K2C-30-3                        None
# 97        K2C-30-51        K2C-30-51^2021-12-01
# 98         K2C-30-9                        None

# %%
lease_realties_pending=realties_pending\
    .assign(doc_date=realties_pending.lease_realty.apply(lambda x: Lease_Realty.objects.get(pk=x).doc_date if x else None),\
           start_date=realties_pending.lease_realty.apply(lambda x: Lease_Realty.objects.get(pk=x).start_date if x else None),\
           end_date=realties_pending.lease_realty.apply(lambda x: Lease_Realty.objects.get(pk=x).end_date if x else None))\
    .drop('lease_realty', axis=1)
lease_realties_pending.to_csv(join(BASE_DIR, f'_files/lease_realties_pending.csv'), float_format='%.0f', na_rep=None, index=False)

# %%
def date_value_csv(code, dates):
    date_value_pending = pd.read_csv(join(BASE_DIR, f'_files/date_value_pending.csv'))
    accountable_id_list = []
    for item in dates:
        accountable_id_list.append(code)
    if dates:
        pd.concat([date_value_pending, pd.DataFrame({'accountable_id': accountable_id_list, 'date':dates})])\
            .to_csv(join(BASE_DIR, f'_files/date_value_pending.csv'), float_format='%.0f', na_rep=None, index=False)

# %%
pending_dates.apply(lambda x: date_value_csv(x.code, x.pending_date_value_dates), axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 44    None
# 45    None
# 46    None
# 47    None
# 48    None
# 49    None
# 50    None
# 51    None
# 52    None
# 53    None
# 54    None
# 55    None
# 56    None
# 57    None
# 58    None
# 59    None
# 60    None
# 61    None
# 62    None
# 63    None
# 64    None
# 65    None
# 66    None
# 67    None
# 68    None
# 69    None
# 70    None
# 71    None
# dtype: object

# %%
dt=datetime.date(2022, 1, 30)

dt + relativedelta(months=4)
# Out:
# datetime.date(2022, 5, 30)

# %%
accon=Accountable_Concept.objects.all()[23]
accon
# Out:
# <Transaction_Concept: Arriendo Inmueble Residencial^2022-04-01_A6N-13N-62-S102^Vernansa Aragon, Jean Carlos>

# %%
{dt: accon.accountable.subclass_obj().get_value_4_date(dt) for dt in accon.accountable.subclass_obj().monthly_dates()}[accon.date]
# Out:
# 940000
