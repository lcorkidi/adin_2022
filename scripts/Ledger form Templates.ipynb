# %%
import os
from os.path import join
from adin.settings import BASE_DIR

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 500)

# %%
concepts = pd.DataFrame(Accountable_Concept.objects.values()).drop(['state_change_user_id', 'state_change_date', 'state'], axis=1)
concepts
# Out:
#                                                   code  \
# 0    Facturacion Arriendo sin IVA^2022-01-01_A6N-13...
# 1    Facturacion Arriendo sin IVA^2022-02-01_A6N-13...
# 2    Facturacion Arriendo sin IVA^2022-03-01_A6N-13...
# 3    Facturacion Arriendo sin IVA^2022-04-01_A6N-13...
# 4    Facturacion Arriendo sin IVA^2022-05-01_A6N-13...
# 5    Facturacion Arriendo sin IVA^2022-06-01_A6N-13...
# 6    Facturacion Arriendo sin IVA^2022-07-01_A6N-13...
# 7    Facturacion Arriendo sin IVA^2022-08-01_A6N-13...
# 8    Facturacion Arriendo sin IVA^2022-01-01_A6N-13...
# 9    Facturacion Arriendo sin IVA^2022-02-01_A6N-13...
# 10   Facturacion Arriendo sin IVA^2022-03-01_A6N-13...
# 11   Facturacion Arriendo sin IVA^2022-04-01_A6N-13...
# 12   Facturacion Arriendo sin IVA^2022-05-01_A6N-13...
# 13   Facturacion Arriendo sin IVA^2022-06-01_A6N-13...
# 14   Facturacion Arriendo sin IVA^2022-07-01_A6N-13...
# 15   Facturacion Arriendo sin IVA^2022-08-01_A6N-13...
# ...

# %%
template=Ledger_Template.objects.all()[0]
template
# Out:
# <Ledger_Template: FV^Arriendo Inmueble_Facturacion Arriendo sin IVA>

# %%
def ledger_from_template(concept):
    ledger = Ledger(
        
        )
