# %%
import os
from os.path import join
from adin.settings import BASE_DIR

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
objs=pd.DataFrame(Person.objects.values()).drop(['state_change_user_id', 'state_change_date', 'state'], axis=1)
objs
# Out:
#       id_number  id_type  type                  name  \
# 0      14440244        0     0          Campo Ramiro
# 1      16375922        0     0        Javier Alberto
# 2     900244841        1     1  Actividades Textiles
# 3      31202432        0     0          María Teresa
# 4      94459724        0     0                Edison
# ..          ...      ...   ...                   ...
# 222  1144172037        0     0           José Miguel
# 223  1193172681        0     0           Jean Carlos
# 224    16700013        0     0               Gonzalo
# 225    16355941        0     0        Alberto Javier
# 226  1107086162        0     0             Valentina
#
#                        complete_name
# 0        Acosta Burgos, Campo Ramiro
# 1    Acosta González, Javier Alberto
# 2        Actividades Textiles S.A.S.
# 3        Agudelo Velez, María Teresa
# 4            Aguiño Mosquera, Edison
# ..                               ...
# 222       Velazco Renza, José Miguel
# ...

# %%
objs1=objs.assign(errors=objs.id_number.apply(lambda x: Person.objects.get(pk=x).get_obj_errors()))
objs1
# Out:
#       id_number  id_type  type                  name  \
# 0      14440244        0     0          Campo Ramiro
# 1      16375922        0     0        Javier Alberto
# 2     900244841        1     1  Actividades Textiles
# 3      31202432        0     0          María Teresa
# 4      94459724        0     0                Edison
# ..          ...      ...   ...                   ...
# 222  1144172037        0     0           José Miguel
# 223  1193172681        0     0           Jean Carlos
# 224    16700013        0     0               Gonzalo
# 225    16355941        0     0        Alberto Javier
# 226  1107086162        0     0             Valentina
#
#                        complete_name                errors
# 0        Acosta Burgos, Campo Ramiro          [11, 22, 20]
# 1    Acosta González, Javier Alberto          [11, 22, 20]
# 2        Actividades Textiles S.A.S.  [16, 17, 27, 28, 29]
# 3        Agudelo Velez, María Teresa          [11, 22, 20]
# ...

# %%
objs1.to_csv(join(BASE_DIR, f'_files/reports/{datetime.date.today().strftime("%Y-%m-%d")}_person_errors.csv'), float_format='%.0f', na_rep=None, index=False)

# %%
obj=pd.DataFrame(Phone.objects.filter(pk='+57 2 5546462').values())
obj
# Out:
#    state_change_user_id                state_change_date  state  \
# 0                     1 2022-07-28 19:59:24.447006+00:00      1
#
#             code  type  country  region   number
# 0  +57 2 5546462     0       57       2  5546462

# %%
for item in Person.objects.all():
    print((item, item.get_obj_errors()))
# Out:
# (<Person: Acosta Burgos, Campo Ramiro>, [11, 22, 20])
# (<Person: Acosta González, Javier Alberto>, [11, 22, 20])
# (<Person: Actividades Textiles S.A.S.>, [16, 17, 27, 28, 29])
# (<Person: Agudelo Velez, María Teresa>, [11, 22, 20])
# (<Person: Aguiño Mosquera, Edison>, [])
# (<Person: Alimentos Carnicos S.A.S.>, [16, 17, 27, 28, 29])
# (<Person: Alimentos Carnicos S.A.S.>, [17, 28, 29, 20])
# (<Person: Amaya Guzman, Diego Fernando>, [11, 22, 20])
# (<Person: Andiplast Envases S.A.S.>, [16, 17, 27, 28, 29])
# (<Person: Arango Monsalve, Yenny Coromoto>, [11, 22, 20])
# (<Person: Arango de Vernaza, Miryan>, [11, 22, 20])
# (<Person: Arbelaez Ceballos, Luis Alberto>, [20])
# (<Person: Arias Murillo, Víctor Hugo>, [11, 22, 20])
# (<Person: Arquimaderas S.A.S.>, [17, 27, 28, 29, 20])
# (<Person: Arévalo Páez, Enrique>, [11, 22, 20])
# (<Person: Asoboce S.A.S.>, [16, 17, 27, 28, 29])
# (<Person: Ballesteros Gallego, Clara Tatiana>, [11, 22, 20])
# (<Person: Baloco, Livio>, [11, 22, 20])
# ...
