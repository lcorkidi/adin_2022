# %%
import os
from os.path import join
from adin.settings import BASE_DIR

from adin.utils.date_progression import nextmonthlydate, nextyearlydate, previousmonthlydate, previousyearlydate

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

pd.set_option('display.max_rows', 500)

# %%
cls = Lease_Realty

# %%
objs_df = pd.DataFrame(cls.objects.values()).drop(['state_change_user_id', 'state_change_date', 'state'], axis=1)
objs_df
# Out:
#                           code  subclass_id          accountable_ptr_id  \
# 0     A6N-13N-62-O1^2015-01-01           33    A6N-13N-62-O1^2015-01-01
# 1   A6N-13N-62-S101^2021-04-01           33  A6N-13N-62-S101^2021-04-01
# 2   A6N-13N-62-S102^2021-10-01           33  A6N-13N-62-S102^2021-10-01
# 3   A6N-13N-62-S103^2020-06-01           33  A6N-13N-62-S103^2020-06-01
# 4   A6N-13N-62-S103^2022-05-01           33  A6N-13N-62-S103^2022-05-01
# 5   A6N-13N-62-S104^2021-08-01           33  A6N-13N-62-S104^2021-08-01
# 6   A6N-13N-62-S105^2021-09-01           33  A6N-13N-62-S105^2021-09-01
# 7   A6N-13N-62-S108^2016-12-01           33  A6N-13N-62-S108^2016-12-01
# 8   A6N-13N-62-S109^2021-07-01           33  A6N-13N-62-S109^2021-07-01
# 9   A6N-13N-62-S110^2021-09-01           33  A6N-13N-62-S110^2021-09-01
# 10  A6N-13N-62-S111^2021-04-01           33  A6N-13N-62-S111^2021-04-01
# 11  A6N-13N-62-S111^2022-07-01           33  A6N-13N-62-S111^2022-07-01
# ...

# %%
errors_df=objs_df.assign(errors=objs_df.code.apply(lambda x: cls.objects.get(pk=x).get_obj_errors()))
errors_df
# Out:
#                           code  subclass_id          accountable_ptr_id  \
# 0     A6N-13N-62-O1^2015-01-01           33    A6N-13N-62-O1^2015-01-01
# 1   A6N-13N-62-S101^2021-04-01           33  A6N-13N-62-S101^2021-04-01
# 2   A6N-13N-62-S102^2021-10-01           33  A6N-13N-62-S102^2021-10-01
# 3   A6N-13N-62-S103^2020-06-01           33  A6N-13N-62-S103^2020-06-01
# 4   A6N-13N-62-S103^2022-05-01           33  A6N-13N-62-S103^2022-05-01
# 5   A6N-13N-62-S104^2021-08-01           33  A6N-13N-62-S104^2021-08-01
# 6   A6N-13N-62-S105^2021-09-01           33  A6N-13N-62-S105^2021-09-01
# 7   A6N-13N-62-S108^2016-12-01           33  A6N-13N-62-S108^2016-12-01
# 8   A6N-13N-62-S109^2021-07-01           33  A6N-13N-62-S109^2021-07-01
# 9   A6N-13N-62-S110^2021-09-01           33  A6N-13N-62-S110^2021-09-01
# 10  A6N-13N-62-S111^2021-04-01           33  A6N-13N-62-S111^2021-04-01
# 11  A6N-13N-62-S111^2022-07-01           33  A6N-13N-62-S111^2022-07-01
# ...

# %%
has_errors_df=objs_df.assign(errors=objs_df.code.apply(lambda x: 0 if len(cls.objects.get(pk=x).get_obj_errors()) == 0 else 1))
has_errors_list=list(has_errors_df[has_errors_df.errors == 1]['code'])
has_errors_list
# Out:
# ['A6N-13N-62-S221^2018-06-15', 'K1-17-57^2001-09-01', 'C18-1N-41^2021-02-01']

# %%
cls.objects.filter(code__in=has_errors_list)
# Out:
# <QuerySet [<Lease_Realty: A6N-13N-62-S221^2018-06-15>, <Lease_Realty: C18-1N-41^2021-02-01>, <Lease_Realty: K1-17-57^2001-09-01>]>
